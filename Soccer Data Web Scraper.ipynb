# %%
import json
import time

import numpy as np
import pandas as pd
# Using Pandas Version 1.5.2

from bs4 import BeautifulSoup

from pydantic import BaseModel
from typing import List, Optional

from selenium import webdriver
# Ensure webdriver is downloaded for current chrome version

from supabase import create_client, Client

# %%
# Assign BeautifulSoup class to alias "BS"
from bs4 import BeautifulSoup as BS

import bs4
import soupsieve

# %%
# Initiate new instance of chrome webdriver using selenium
driver = webdriver.Chrome()

# %%
# Match Data: Inter 1-0 Juventus (Feb. 4th, 2024) 
whoscored_url = "https://www.whoscored.com/Matches/1746287/Live/Italy-Serie-A-2023-2024-Inter-Juventus"

# %%
# Opens specified URL
driver.get(whoscored_url)

# %%
# Retrives HTML source code and parses it
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Select element with the matchCentreData
element = soup.select_one('script:-soup-contains("matchCentreData")')

# %%
# Extracts & loads JSON data, loads it into dictionary
matchdict = json.loads(element.text.split("matchCentreData: ")[1].split(',\n')[0])

# %%
# Keys in dictionary
matchdict.keys()
# Out:
# dict_keys(['playerIdNameDictionary', 'periodMinuteLimits', 'timeStamp', 'attendance', 'venueName', 'referee', 'weatherCode', 'elapsed', 'startTime', 'startDate', 'score', 'htScore', 'ftScore', 'etScore', 'pkScore', 'statusCode', 'periodCode', 'home', 'away', 'maxMinute', 'minuteExpanded', 'maxPeriod', 'expandedMinutes', 'expandedMaxMinute', 'periodEndMinutes', 'commonEvents', 'events', 'timeoutInSeconds'])

# %%
matchdict['events'][55]
# Out:
# {'id': 2642983473.0,
#  'eventId': 30,
#  'minute': 2,
#  'second': 36,
#  'teamId': 87,
#  'playerId': 105995,
#  'x': 2.6,
#  'y': 87.5,
#  'expandedMinute': 2,
#  'period': {'value': 1, 'displayName': 'FirstHalf'},
#  'type': {'value': 56, 'displayName': 'ShieldBallOpp'},
#  'outcomeType': {'value': 1, 'displayName': 'Successful'},
#  'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#    'value': 'Back'}],
#  'satisfiedEventsTypes': [],
#  'isTouch': False}

# %%
# Assign list to variable
match_events = matchdict['events']

# %%
# Create DataFrame using 'events' data
df = pd.DataFrame(match_events)

# %%
# Return first 5 rows
df.head()
# Out:
#              id  eventId  minute  second  teamId     x     y  expandedMinute  \
# 0  2.642982e+09        2       0       0      87   0.0   0.0               0
# 1  2.642982e+09        2       0       0      75   0.0   0.0               0
# 2  2.642982e+09        3       0       0      87  50.1  50.1               0
# 3  2.642982e+09        4       0       2      87  37.2  44.6               0
# 4  2.642982e+09        4       0      12      75  33.1   0.0               0
#
#                                      period  \
# 0  {'value': 1, 'displayName': 'FirstHalf'}
# 1  {'value': 1, 'displayName': 'FirstHalf'}
# 2  {'value': 1, 'displayName': 'FirstHalf'}
# 3  {'value': 1, 'displayName': 'FirstHalf'}
# 4  {'value': 1, 'displayName': 'FirstHalf'}
#
#                                     type  ... relatedEventId relatedPlayerId  \
# 0  {'value': 32, 'displayName': 'Start'}  ...            NaN             NaN
# 1  {'value': 32, 'displayName': 'Start'}  ...            NaN             NaN
# 2    {'value': 1, 'displayName': 'Pass'}  ...            NaN             NaN
# 3    {'value': 1, 'displayName': 'Pass'}  ...            NaN             NaN
# 4    {'value': 1, 'displayName': 'Pass'}  ...            NaN             NaN
#
#   blockedX  blockedY  goalMouthZ  goalMouthY  isShot  cardType  isOwnGoal  \
# 0      NaN       NaN         NaN         NaN     NaN       NaN        NaN
# 1      NaN       NaN         NaN         NaN     NaN       NaN        NaN
# 2      NaN       NaN         NaN         NaN     NaN       NaN        NaN
# 3      NaN       NaN         NaN         NaN     NaN       NaN        NaN
# 4      NaN       NaN         NaN         NaN     NaN       NaN        NaN
#
#    isGoal
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 27 columns]

# %%
# Remove rows where 'playerId' has missing values (NaN)
df.dropna(subset='playerId', inplace=True)

# %% [markdown]
# nan, None, NaN

# %%
# Replace missing vlaues with 'None'
df = df.where(pd.notnull(df), None)

# %% [markdown]
# event_id, team_id, outcome_type

# %%
# Rename columns
df = df.rename(
    {
        'eventId': 'event_id',
        'expandedMinute': 'expanded_minute',
        'outcomeType': 'outcome_type',
        'isTouch': 'is_touch',
        'playerId': 'player_id',
        'teamId': 'team_id',
        'endX': 'end_x',
        'endY': 'end_y',
        'blockedX': 'blocked_x',
        'blockedY': 'blocked_y',
        'goalMouthZ': 'goal_mouth_z',
        'goalMouthY': 'goal_mouth_y',
        'isShot': 'is_shot',
        'cardType': 'card_type',
        'isGoal': 'is_goal'
    },
    axis=1
)

# %%
# Creates new column with 'displayName' values
df['period_display_name'] = df['period'].apply(lambda x: x['displayName'])

# Creates a new column with 'displayName' values
df['type_display_name'] = df['type'].apply(lambda x: x['displayName'])

# Creates a new column with 'displayName' values
df['outcome_type_display_name'] = df['outcome_type'].apply(lambda x: x['displayName'])

# %%
# Drops specified columns
df.drop(columns=["period", "type", "outcome_type"], inplace=True)

# %%
# Check if 'is_goal' column is missing (for 0-0 matches)
if 'is_goal' not in df.columns:
    print('missing goals')
    df['is_goal'] = False

# %%
# Returns the number of rows
len(df.index)
# Out:
# 1634

# %%
# Removes rows where 'type_display_name' is "OffsideGiven"
# Avoids inconsistencies with URL database
df = df[~(df['type_display_name'] == "OffsideGiven")]

# %%
# display columns
df.columns
# Out:
# Index(['id', 'event_id', 'minute', 'second', 'team_id', 'x', 'y',
#        'expanded_minute', 'qualifiers', 'satisfiedEventsTypes', 'is_touch',
#        'player_id', 'end_x', 'end_y', 'relatedEventId', 'relatedPlayerId',
#        'blocked_x', 'blocked_y', 'goal_mouth_z', 'goal_mouth_y', 'is_shot',
#        'card_type', 'isOwnGoal', 'is_goal', 'period_display_name',
#        'type_display_name', 'outcome_type_display_name'],
#       dtype='object')

# %%
# Keep these columns
df = df[[
    'id', 'event_id', 'minute', 'second', 'team_id', 'player_id', 'x', 'y', 'end_x', 'end_y',
    'qualifiers', 'is_touch', 'blocked_x', 'blocked_y', 'goal_mouth_z', 'goal_mouth_y', 'is_shot',
    'card_type', 'is_goal', 'type_display_name', 'outcome_type_display_name',
    'period_display_name'
]]

# %%
# Display data types
df.dtypes
# Out:
# id                           float64
# event_id                       int64
# minute                         int64
# second                         int64
# team_id                        int64
# player_id                    float64
# x                            float64
# y                            float64
# end_x                        float64
# end_y                        float64
# qualifiers                    object
# is_touch                        bool
# blocked_x                    float64
# blocked_y                    float64
# goal_mouth_z                 float64
# goal_mouth_y                 float64
# is_shot                       object
# card_type                     object
# is_goal                       object
# type_display_name             object
# outcome_type_display_name     object
# period_display_name           object
# dtype: object

# %%
# Convert to appropriate data types
df[['id', 'event_id', 'minute', 'team_id', 'player_id']] = df[['id', 'event_id', 'minute', 'team_id', 'player_id']].astype(np.int64)
df[['second', 'x', 'y', 'end_x', 'end_y']] = df[['second', 'x', 'y', 'end_x', 'end_y']].astype(float)
df[['is_shot', 'is_goal', 'card_type']] = df[['is_shot', 'is_goal', 'card_type']].astype(bool)

# %%
# Insert NaN values in columns with False
df['is_goal'] = df['is_goal'].fillna(False)
df['is_shot'] = df['is_shot'].fillna(False)

# %%
# Replace NaN values in columns with float64 or float32 data types with None 
for column in df.columns:
    if df[column].dtype == np.float64 or df[column].dtype == np.float32:
        df[column] = np.where(
            np.isnan(df[column]),
            None,
            df[column]
        )

# %%
# Convert first row to a dictionary
df.iloc[0].to_dict()
# Out:
# {'id': 2642982317,
#  'event_id': 3,
#  'minute': 0,
#  'second': 0.0,
#  'team_id': 87,
#  'player_id': 315369,
#  'x': 50.1,
#  'y': 50.1,
#  'end_x': 36.7,
#  'end_y': 44.4,
#  'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#    'value': '44.4'},
#   {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '3.41'},
#   {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.6'},
#   {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '36.7'},
#   {'type': {'value': 178, 'displayName': 'StandingSave'}},
#   {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#  'is_touch': True,
#  'blocked_x': None,
#  'blocked_y': None,
#  'goal_mouth_z': None,
#  'goal_mouth_y': None,
#  'is_shot': False,
#  'card_type': False,
#  'is_goal': False,
#  'type_display_name': 'Pass',
#  'outcome_type_display_name': 'Successful',
#  'period_display_name': 'FirstHalf'}

# %%
# Define Pydantic model
class MatchEvent(BaseModel):
    
    # Unique identifier for match event
    id: int
    
    # Identifier for specific event
    event_id: int
    
    # The minute when event occurred
    minute: int
        
    # The second within the minute, if applicable
    second: Optional[float] = None
    
    # Identifier for the team associated with the event
    team_id: int
        
    # Identifier for the player associated with the event
    player_id: int
        
    # X-coordinate of  event location on field
    x: float
        
    # Y-coordinate of  event location on field
    y: float
        
    # X-coordinate of the end location, if applicable
    end_x: Optional[float] = None
    
    # Y-coordinate of the end location, if applicable
    end_y: Optional[float] = None
        
    # List of qualifiers providing additional details
    qualifiers: List[dict]
        
    # Indicates whether the event involves a player's touch
    is_touch: bool
        
    # X-coordinate of a blocked event, if applicable
    blocked_x: Optional[float] = None
    
    # Y-coordinate of a blocked event, if applicable
    blocked_y: Optional[float] = None
        
    # Note: "goal_mouth" refers to area in front of goal
    # Z-coordinate of the goal mouth, if applicable
    goal_mouth_z: Optional[float] = None
    
    # Y-coordinate of the goal mouth, if applicable
    goal_mouth_y: Optional[float] = None
        
    # Indicates whether  event is a shot on goal
    is_shot: bool
        
    # Indicates whether  event involves a card being issued
    card_type: bool
        
    # Indicates whether the event resulted in a goal
    is_goal: bool
    
    # Display name indicating type of event
    type_display_name: str
        
    # Display name indicating  outcome type of event
    outcome_type_display_name: str
        
    # Display name indicating period when event occurred
    period_display_name: str

# %%
# Create MatchEvent objects
for x in df.to_dict(orient="records"):
    try:
        # Create object and convert it to dictionary
        MatchEvent(**x).model_dump()
    except Exception as e:
        # Print exception
        print(e)
        break

# %%
x
# Out:
# {'id': 2643035309,
#  'event_id': 851,
#  'minute': 94,
#  'second': 35.0,
#  'team_id': 87,
#  'player_id': 425080,
#  'x': 87.4,
#  'y': 14.4,
#  'end_x': 84.2,
#  'end_y': 100.0,
#  'qualifiers': [{'type': {'value': 178, 'displayName': 'StandingSave'}},
#   {'type': {'value': 212, 'displayName': 'Length'}, 'value': '59.7'},
#   {'type': {'value': 2, 'displayName': 'Cross'}},
#   {'type': {'value': 155, 'displayName': 'Chipped'}},
#   {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '84.2'},
#   {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#   {'type': {'value': 20, 'displayName': 'RightFoot'}},
#   {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '100.0'},
#   {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.63'},
#   {'type': {'value': 1, 'displayName': 'Longball'}}],
#  'is_touch': True,
#  'blocked_x': None,
#  'blocked_y': None,
#  'goal_mouth_z': None,
#  'goal_mouth_y': None,
#  'is_shot': False,
#  'card_type': False,
#  'is_goal': False,
#  'type_display_name': 'Pass',
#  'outcome_type_display_name': 'Unsuccessful',
#  'period_display_name': 'SecondHalf'}

# %%
supabase_password = '7eZZSE#$e+U6B.s'

# %%
project_url = 'https://vrvkafgbdruqmzszmaln.supabase.co'
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InZydmthZmdiZHJ1cW16c3ptYWxuIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MDcyMzQ1OTAsImV4cCI6MjAyMjgxMDU5MH0.RnA_99mq99SmSYLTuin-GFSOt5ax4mCThVGXYVFov9A'

# %%
# Grouping by "id" and counting occurences to show frequency
df.groupby('id').count().sort_values(by='event_id', ascending=False)
# Out:
#             event_id  minute  second  team_id  player_id  x  y  end_x  end_y  \
# id
# 2642982317         1       1       1        1          1  1  1      1      1
# 2643016461         1       1       1        1          1  1  1      1      1
# 2643016697         1       1       1        1          1  1  1      1      1
# 2643016669         1       1       1        1          1  1  1      1      1
# 2643016661         1       1       1        1          1  1  1      1      1
# ...              ...     ...     ...      ...        ... .. ..    ...    ...
# 2642996273         1       1       1        1          1  1  1      1      1
# 2642996243         1       1       1        1          1  1  1      1      1
# 2642996197         1       1       1        1          1  1  1      1      1
# 2642996155         1       1       1        1          1  1  1      1      1
# 2643090601         1       1       1        1          1  1  1      0      0
#
#             qualifiers  ...  blocked_x  blocked_y  goal_mouth_z  goal_mouth_y  \
# id                      ...
# 2642982317           1  ...          0          0             0             0
# 2643016461           1  ...          0          0             0             0
# 2643016697           1  ...          0          0             0             0
# 2643016669           1  ...          0          0             0             0
# 2643016661           1  ...          0          0             0             0
# ...                ...  ...        ...        ...           ...           ...
# 2642996273           1  ...          0          0             0             0
# 2642996243           1  ...          0          0             0             0
# 2642996197           1  ...          0          0             0             0
# 2642996155           1  ...          0          0             0             0
# 2643090601           1  ...          0          0             0             0
#
#             is_shot  card_type  is_goal  type_display_name  \
# id
# 2642982317        1          1        1                  1
# 2643016461        1          1        1                  1
# 2643016697        1          1        1                  1
# 2643016669        1          1        1                  1
# 2643016661        1          1        1                  1
# ...             ...        ...      ...                ...
# 2642996273        1          1        1                  1
# 2642996243        1          1        1                  1
# 2642996197        1          1        1                  1
# 2642996155        1          1        1                  1
# 2643090601        1          1        1                  1
#
#             outcome_type_display_name  period_display_name
# id
# 2642982317                          1                    1
# 2643016461                          1                    1
# 2643016697                          1                    1
# 2643016669                          1                    1
# 2643016661                          1                    1
# ...                               ...                  ...
# 2642996273                          1                    1
# 2642996243                          1                    1
# 2642996197                          1                    1
# 2642996155                          1                    1
# 2643090601                          1                    1
#
# [1634 rows x 21 columns]

# %%
# Insert match events into Supabase tables
def insert_match_events(df, supabase):
    # Create a list of MatchEvent dictionaries
    events = [
        MatchEvent(**x).model_dump()
        for x in df.to_dict(orient='records')
    ]
    # Use Supabase upsert to insert or update records in the 'match_events' table
    execution = supabase.table('match_events').upsert(events).execute()

# %%
# Create Supabase client using project URL and API key
supabase = create_client(project_url, api_key)

# %%
# Insert match events from DataFrame into  'match_events' table
insert_match_events(df, supabase)
# Out:
# 2024-02-07 17:28:21,695:INFO - HTTP Request: POST https://vrvkafgbdruqmzszmaln.supabase.co/rest/v1/match_events "HTTP/1.1 200 OK"

# %%
# Create team information list for home team
team_info = []
team_info.append({
    'team_id': matchdict['home']['teamId'],
    'name': matchdict['home']['name'],
    'country_name': matchdict['home']['countryName'],
    'manager_name': matchdict['home']['managerName'],
    'players': matchdict['home']['players'],
})

# Create team information list for away team
team_info.append({
    'team_id': matchdict['away']['teamId'],
    'name': matchdict['away']['name'],
    'country_name': matchdict['away']['countryName'],
    'manager_name': matchdict['away']['managerName'],
    'players': matchdict['away']['players'],
})

# %%
matchdict['home']['players']
# Out:
# [{'playerId': 35758,
#   'shirtNo': 1,
#   'name': 'Yann Sommer',
#   'position': 'GK',
#   'height': 183,
#   'weight': 79,
#   'age': 35,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'totalSaves': {'73': 1.0},
#    'collected': {'73': 1.0},
#    'possession': {'6': 2.0,
#     '8': 1.0,
#     '10': 1.0,
#     '15': 1.0,
#     '33': 1.0,
#     '38': 2.0,
#     '44': 2.0,
#     '47': 3.0,
#     '50': 2.0,
#     '54': 1.0,
#     '56': 1.0,
#     '64': 1.0,
#     '69': 1.0,
#     '73': 1.0,
#     '76': 3.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 2.0,
#     '88': 2.0,
#     '90': 1.0,
#     '92': 1.0},
#    'ratings': {'0': 6.0,
#     '6': 6.0,
#     '8': 6.0,
#     '10': 6.01,
#     '15': 6.01,
#     '33': 6.01,
#     '36': 6.06,
#     '38': 6.07,
#     '44': 6.06,
#     '47': 6.07,
#     '50': 6.05,
#     '54': 6.06,
#     '56': 6.06,
#     '64': 6.07,
#     '69': 6.07,
#     '73': 6.18,
#     '76': 6.18,
#     '77': 6.18,
#     '81': 6.19,
#     '83': 6.21,
#     '88': 6.21,
#     '90': 6.22,
#     '92': 6.24,
#     '97': 6.57},
#    'touches': {'6': 2.0,
#     '8': 1.0,
#     '10': 1.0,
#     '15': 1.0,
#     '33': 1.0,
#     '38': 2.0,
#     '44': 2.0,
#     '47': 3.0,
#     '50': 2.0,
#     '54': 1.0,
#     '56': 1.0,
#     '64': 1.0,
#     '69': 1.0,
#     '73': 2.0,
#     '76': 3.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 2.0,
#     '88': 2.0,
#     '90': 1.0,
#     '92': 1.0},
#    'passesTotal': {'6': 2.0,
#     '8': 1.0,
#     '10': 1.0,
#     '15': 1.0,
#     '33': 1.0,
#     '38': 1.0,
#     '44': 2.0,
#     '47': 3.0,
#     '50': 2.0,
#     '54': 1.0,
#     '56': 1.0,
#     '64': 1.0,
#     '69': 1.0,
#     '76': 3.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 2.0,
#     '88': 1.0,
#     '90': 1.0,
#     '92': 1.0},
#    'passesAccurate': {'6': 2.0,
#     '8': 1.0,
#     '10': 1.0,
#     '15': 1.0,
#     '33': 1.0,
#     '38': 1.0,
#     '44': 1.0,
#     '47': 3.0,
#     '50': 1.0,
#     '54': 1.0,
#     '56': 1.0,
#     '64': 1.0,
#     '69': 1.0,
#     '76': 3.0,
#     '77': 1.0,
#     '81': 1.0,
#     '83': 2.0,
#     '88': 1.0,
#     '90': 1.0,
#     '92': 1.0},
#    'passSuccess': {'6': 100.0,
#     '8': 100.0,
#     '10': 100.0,
#     '15': 100.0,
#     '33': 100.0,
#     '38': 100.0,
#     '44': 50.0,
#     '47': 100.0,
#     '50': 50.0,
#     '54': 100.0,
#     '56': 100.0,
#     '64': 100.0,
#     '69': 100.0,
#     '76': 100.0,
#     '77': 100.0,
#     '81': 100.0,
#     '83': 100.0,
#     '88': 100.0,
#     '90': 100.0,
#     '92': 100.0}}},
#  {'playerId': 259648,
#   'shirtNo': 28,
#   'name': 'Benjamin Pavard',
#   'position': 'DC',
#   'height': 186,
#   'weight': 76,
#   'age': 27,
#   'isFirstEleven': True,
#   'isManOfTheMatch': True,
#   'field': 'home',
#   'stats': {'possession': {'0': 3.0,
#     '3': 2.0,
#     '7': 2.0,
#     '9': 1.0,
#     '11': 1.0,
#     '14': 3.0,
#     '15': 3.0,
#     '16': 2.0,
#     '17': 2.0,
#     '18': 1.0,
#     '19': 2.0,
#     '20': 1.0,
#     '22': 3.0,
#     '30': 4.0,
#     '33': 2.0,
#     '35': 4.0,
#     '38': 1.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 2.0,
#     '47': 2.0,
#     '48': 2.0,
#     '50': 1.0,
#     '51': 1.0,
#     '54': 1.0,
#     '57': 3.0,
#     '59': 3.0,
#     '66': 1.0,
#     '69': 1.0,
#     '74': 1.0,
#     '76': 1.0,
#     '83': 2.0,
#     '84': 3.0,
#     '94': 1.0},
#    'ratings': {'0': 6.02,
#     '3': 6.03,
#     '6': 6.06,
#     '7': 6.07,
#     '9': 6.07,
#     '11': 6.07,
#     '13': 6.12,
#     '14': 6.13,
#     '15': 6.12,
#     '16': 6.13,
#     '17': 6.3,
#     '18': 6.3,
#     '19': 6.3,
#     '20': 6.3,
#     '22': 6.32,
#     '26': 6.45,
#     '30': 6.46,
#     '31': 6.55,
#     '33': 6.55,
#     '34': 6.63,
#     '35': 6.65,
#     '36': 6.72,
#     '38': 6.73,
#     '41': 6.73,
#     '43': 6.74,
#     '44': 6.74,
#     '45': 6.79,
#     '47': 6.79,
#     '48': 6.8,
#     '49': 6.78,
#     '50': 6.78,
#     '51': 6.78,
#     '54': 6.78,
#     '57': 6.8,
#     '59': 6.8,
#     '61': 6.87,
#     '66': 6.88,
#     '69': 6.87,
#     '70': 7.0,
#     '72': 7.05,
#     '74': 7.06,
#     '76': 7.16,
#     '83': 7.16,
#     '84': 7.18,
#     '91': 7.26,
#     '94': 7.25,
#     '96': 7.24,
#     '97': 7.5},
#    'clearances': {'45': 1.0, '72': 1.0},
#    'interceptions': {'76': 1.0},
#    'touches': {'0': 3.0,
#     '3': 2.0,
#     '6': 1.0,
#     '7': 2.0,
#     '9': 1.0,
#     '11': 1.0,
#     '13': 1.0,
#     '14': 3.0,
#     '15': 3.0,
#     '16': 2.0,
#     '17': 2.0,
#     '18': 1.0,
#     '19': 2.0,
#     '20': 1.0,
#     '22': 3.0,
#     '26': 1.0,
#     '30': 4.0,
#     '31': 1.0,
#     '33': 2.0,
#     '34': 1.0,
#     '35': 4.0,
#     '38': 1.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 3.0,
#     '47': 2.0,
#     '48': 2.0,
#     '50': 1.0,
#     '51': 1.0,
#     '54': 1.0,
#     '57': 3.0,
#     '59': 3.0,
#     '61': 1.0,
#     '66': 1.0,
#     '69': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '74': 1.0,
#     '76': 2.0,
#     '83': 2.0,
#     '84': 4.0,
#     '87': 1.0,
#     '91': 1.0,
#     '94': 1.0},
#    'passesTotal': {'0': 3.0,
#     '3': 2.0,
#     '7': 2.0,
#     '9': 1.0,
#     '11': 1.0,
#     '14': 3.0,
#     '15': 3.0,
#     '16': 2.0,
#     '17': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '22': 3.0,
#     '30': 4.0,
#     '33': 2.0,
#     '35': 4.0,
#     '38': 1.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 2.0,
#     '47': 2.0,
#     '48': 2.0,
#     '50': 1.0,
#     '51': 1.0,
#     '54': 1.0,
#     '57': 3.0,
#     '59': 3.0,
#     '66': 1.0,
#     '74': 1.0,
#     '76': 1.0,
#     '83': 2.0,
#     '84': 3.0,
#     '20': 1.0,
#     '69': 1.0,
#     '94': 1.0},
#    'passesAccurate': {'0': 3.0,
#     '3': 2.0,
#     '7': 2.0,
#     '9': 1.0,
#     '11': 1.0,
#     '14': 2.0,
#     '15': 3.0,
#     '16': 2.0,
#     '17': 1.0,
#     '18': 1.0,
#     '19': 2.0,
#     '22': 3.0,
#     '30': 4.0,
#     '33': 2.0,
#     '35': 4.0,
#     '38': 1.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 1.0,
#     '47': 2.0,
#     '48': 2.0,
#     '50': 1.0,
#     '51': 1.0,
#     '54': 1.0,
#     '57': 3.0,
#     '59': 2.0,
#     '66': 1.0,
#     '74': 1.0,
#     '76': 1.0,
#     '83': 2.0,
#     '84': 3.0},
#    'passesKey': {'17': 1.0},
#    'passSuccess': {'0': 100.0,
#     '3': 100.0,
#     '7': 100.0,
#     '9': 100.0,
#     '11': 100.0,
#     '14': 66.67,
#     '15': 100.0,
#     '16': 100.0,
#     '17': 100.0,
#     '18': 100.0,
#     '19': 100.0,
#     '22': 100.0,
#     '30': 100.0,
#     '33': 100.0,
#     '35': 100.0,
#     '38': 100.0,
#     '41': 100.0,
#     '43': 100.0,
#     '44': 100.0,
#     '45': 50.0,
#     '47': 100.0,
#     '48': 100.0,
#     '50': 100.0,
#     '51': 100.0,
#     '54': 100.0,
#     '57': 100.0,
#     '59': 66.67,
#     '66': 100.0,
#     '74': 100.0,
#     '76': 100.0,
#     '83': 100.0,
#     '84': 100.0,
#     '20': 0.0,
#     '69': 0.0,
#     '94': 0.0},
#    'aerialsTotal': {'15': 1.0, '49': 1.0, '61': 1.0, '96': 1.0},
#    'offensiveAerials': {'49': 1.0},
#    'defensiveAerials': {'15': 1.0, '61': 1.0, '96': 1.0},
#    'tacklesTotal': {'26': 1.0, '70': 1.0, '91': 1.0},
#    'tackleSuccessful': {'26': 1.0, '70': 1.0, '91': 1.0},
#    'tackleSuccess': {'26': 100.0, '70': 100.0, '91': 100.0}}},
#  {'playerId': 329665,
#   'shirtNo': 95,
#   'name': 'Alessandro Bastoni',
#   'position': 'DC',
#   'height': 190,
#   'weight': 75,
#   'age': 24,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 82399,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 90,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 3.0,
#     '1': 2.0,
#     '3': 2.0,
#     '4': 1.0,
#     '6': 2.0,
#     '7': 1.0,
#     '8': 1.0,
#     '9': 2.0,
#     '10': 2.0,
#     '11': 1.0,
#     '14': 4.0,
#     '15': 3.0,
#     '17': 1.0,
#     '21': 1.0,
#     '22': 2.0,
#     '26': 1.0,
#     '29': 2.0,
#     '30': 4.0,
#     '32': 2.0,
#     '38': 3.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 2.0,
#     '47': 3.0,
#     '48': 2.0,
#     '50': 2.0,
#     '55': 1.0,
#     '56': 1.0,
#     '59': 2.0,
#     '65': 1.0,
#     '67': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '77': 1.0,
#     '81': 1.0,
#     '84': 1.0,
#     '88': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 6.0,
#     '3': 6.0,
#     '4': 6.06,
#     '6': 6.05,
#     '7': 6.05,
#     '8': 6.05,
#     '9': 6.06,
#     '10': 6.06,
#     '11': 6.07,
#     '12': 6.17,
#     '14': 6.16,
#     '15': 6.16,
#     '16': 6.29,
#     '17': 6.3,
#     '20': 6.55,
#     '21': 6.6,
#     '22': 6.6,
#     '26': 6.59,
#     '29': 6.65,
#     '30': 6.66,
#     '31': 6.62,
#     '32': 6.63,
#     '36': 6.7,
#     '38': 6.69,
#     '41': 6.7,
#     '42': 6.75,
#     '43': 6.76,
#     '44': 6.76,
#     '45': 6.77,
#     '47': 6.77,
#     '48': 6.78,
#     '50': 6.79,
#     '55': 6.79,
#     '56': 6.79,
#     '59': 6.8,
#     '64': 6.78,
#     '65': 6.78,
#     '67': 6.78,
#     '71': 6.86,
#     '73': 6.86,
#     '76': 6.86,
#     '77': 6.85,
#     '81': 6.84,
#     '84': 6.84,
#     '85': 6.82,
#     '88': 6.83,
#     '90': 7.1},
#    'shotsTotal': {'4': 1.0, '20': 1.0},
#    'shotsOnTarget': {'20': 1.0},
#    'shotsOffTarget': {'4': 1.0},
#    'clearances': {'29': 1.0, '42': 1.0},
#    'interceptions': {'12': 1.0},
#    'touches': {'0': 3.0,
#     '1': 2.0,
#     '3': 2.0,
#     '4': 2.0,
#     '6': 2.0,
#     '7': 1.0,
#     '8': 1.0,
#     '9': 2.0,
#     '10': 2.0,
#     '11': 1.0,
#     '12': 1.0,
#     '14': 4.0,
#     '15': 3.0,
#     '16': 1.0,
#     '17': 1.0,
#     '20': 1.0,
#     '21': 2.0,
#     '22': 2.0,
#     '26': 1.0,
#     '29': 3.0,
#     '30': 4.0,
#     '32': 2.0,
#     '38': 3.0,
#     '41': 2.0,
#     '42': 1.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 3.0,
#     '47': 3.0,
#     '48': 2.0,
#     '49': 1.0,
#     '50': 2.0,
#     '55': 1.0,
#     '56': 1.0,
#     '59': 2.0,
#     '65': 1.0,
#     '67': 1.0,
#     '71': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '77': 1.0,
#     '81': 1.0,
#     '84': 1.0,
#     '85': 1.0,
#     '88': 1.0},
#    'passesTotal': {'0': 3.0,
#     '1': 1.0,
#     '3': 2.0,
#     '4': 1.0,
#     '6': 2.0,
#     '7': 1.0,
#     '8': 1.0,
#     '9': 2.0,
#     '10': 2.0,
#     '11': 1.0,
#     '14': 3.0,
#     '15': 2.0,
#     '17': 1.0,
#     '22': 2.0,
#     '29': 2.0,
#     '30': 4.0,
#     '32': 2.0,
#     '38': 3.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 2.0,
#     '47': 3.0,
#     '48': 2.0,
#     '50': 2.0,
#     '55': 1.0,
#     '56': 1.0,
#     '59': 2.0,
#     '65': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '84': 1.0,
#     '88': 1.0,
#     '26': 1.0,
#     '67': 1.0,
#     '77': 1.0,
#     '81': 1.0},
#    'passesAccurate': {'0': 3.0,
#     '1': 1.0,
#     '3': 2.0,
#     '4': 1.0,
#     '6': 1.0,
#     '7': 1.0,
#     '8': 1.0,
#     '9': 2.0,
#     '10': 2.0,
#     '11': 1.0,
#     '14': 3.0,
#     '15': 2.0,
#     '17': 1.0,
#     '22': 2.0,
#     '29': 2.0,
#     '30': 4.0,
#     '32': 2.0,
#     '38': 2.0,
#     '41': 2.0,
#     '43': 4.0,
#     '44': 2.0,
#     '45': 2.0,
#     '47': 3.0,
#     '48': 2.0,
#     '50': 2.0,
#     '55': 1.0,
#     '56': 1.0,
#     '59': 2.0,
#     '65': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '84': 1.0,
#     '88': 1.0},
#    'passSuccess': {'0': 100.0,
#     '1': 100.0,
#     '3': 100.0,
#     '4': 100.0,
#     '6': 50.0,
#     '7': 100.0,
#     '8': 100.0,
#     '9': 100.0,
#     '10': 100.0,
#     '11': 100.0,
#     '14': 100.0,
#     '15': 100.0,
#     '17': 100.0,
#     '22': 100.0,
#     '29': 100.0,
#     '30': 100.0,
#     '32': 100.0,
#     '38': 66.67,
#     '41': 100.0,
#     '43': 100.0,
#     '44': 100.0,
#     '45': 100.0,
#     '47': 100.0,
#     '48': 100.0,
#     '50': 100.0,
#     '55': 100.0,
#     '56': 100.0,
#     '59': 100.0,
#     '65': 100.0,
#     '73': 100.0,
#     '76': 100.0,
#     '84': 100.0,
#     '88': 100.0,
#     '26': 0.0,
#     '67': 0.0,
#     '77': 0.0,
#     '81': 0.0},
#    'aerialsTotal': {'4': 1.0, '20': 1.0, '64': 1.0},
#    'aerialsWon': {'4': 1.0, '20': 1.0},
#    'aerialSuccess': {'64': 0.0},
#    'offensiveAerials': {'4': 1.0, '20': 1.0},
#    'defensiveAerials': {'64': 1.0},
#    'throwInsTotal': {'45': 1.0, '49': 1.0},
#    'throwInsAccurate': {'45': 1.0},
#    'tacklesTotal': {'16': 1.0, '31': 1.0},
#    'tackleSuccessful': {'16': 1.0},
#    'tackleUnsuccesful': {'31': 1.0},
#    'tackleSuccess': {'16': 100.0, '31': 0.0},
#    'dribbledPast': {'31': 1.0},
#    'dribblesAttempted': {'85': 1.0},
#    'dribblesLost': {'85': 1.0}}},
#  {'playerId': 54968,
#   'shirtNo': 15,
#   'name': 'Francesco Acerbi',
#   'position': 'DC',
#   'height': 192,
#   'weight': 88,
#   'age': 35,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'3': 2.0,
#     '5': 1.0,
#     '6': 3.0,
#     '7': 3.0,
#     '8': 1.0,
#     '9': 3.0,
#     '10': 3.0,
#     '11': 1.0,
#     '15': 2.0,
#     '16': 2.0,
#     '18': 2.0,
#     '21': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '29': 2.0,
#     '30': 1.0,
#     '32': 1.0,
#     '33': 2.0,
#     '38': 2.0,
#     '41': 2.0,
#     '42': 1.0,
#     '43': 2.0,
#     '45': 2.0,
#     '47': 1.0,
#     '48': 4.0,
#     '51': 2.0,
#     '55': 1.0,
#     '59': 2.0,
#     '66': 1.0,
#     '84': 1.0,
#     '88': 1.0,
#     '92': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 5.98,
#     '3': 5.99,
#     '5': 5.99,
#     '6': 5.99,
#     '7': 6.0,
#     '8': 6.0,
#     '9': 6.01,
#     '10': 6.02,
#     '11': 6.03,
#     '15': 6.04,
#     '16': 6.05,
#     '17': 6.08,
#     '18': 6.08,
#     '21': 6.09,
#     '22': 6.09,
#     '24': 6.1,
#     '29': 6.1,
#     '30': 6.11,
#     '32': 6.11,
#     '33': 6.11,
#     '36': 6.18,
#     '38': 6.18,
#     '41': 6.18,
#     '42': 6.24,
#     '43': 6.25,
#     '45': 6.25,
#     '47': 6.25,
#     '48': 6.26,
#     '51': 6.26,
#     '55': 6.32,
#     '59': 6.32,
#     '60': 6.3,
#     '66': 6.31,
#     '70': 6.41,
#     '84': 6.42,
#     '88': 6.47,
#     '92': 6.47,
#     '93': 6.52,
#     '97': 6.78},
#    'shotsTotal': {'11': 1.0},
#    'shotsBlocked': {'11': 1.0},
#    'clearances': {'42': 1.0, '55': 1.0, '88': 1.0, '93': 1.0},
#    'interceptions': {'70': 1.0},
#    'touches': {'3': 2.0,
#     '5': 1.0,
#     '6': 3.0,
#     '7': 3.0,
#     '8': 1.0,
#     '9': 3.0,
#     '10': 3.0,
#     '11': 3.0,
#     '15': 2.0,
#     '16': 3.0,
#     '17': 1.0,
#     '18': 2.0,
#     '21': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '27': 1.0,
#     '29': 2.0,
#     '30': 1.0,
#     '32': 1.0,
#     '33': 2.0,
#     '38': 2.0,
#     '41': 2.0,
#     '42': 2.0,
#     '43': 2.0,
#     '45': 2.0,
#     '47': 1.0,
#     '48': 4.0,
#     '51': 2.0,
#     '55': 2.0,
#     '59': 2.0,
#     '66': 1.0,
#     '70': 1.0,
#     '84': 1.0,
#     '88': 2.0,
#     '92': 1.0,
#     '93': 1.0},
#    'passesTotal': {'3': 2.0,
#     '5': 1.0,
#     '6': 3.0,
#     '7': 3.0,
#     '8': 1.0,
#     '9': 3.0,
#     '10': 3.0,
#     '11': 1.0,
#     '15': 2.0,
#     '16': 2.0,
#     '18': 2.0,
#     '21': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '29': 2.0,
#     '30': 1.0,
#     '32': 1.0,
#     '33': 2.0,
#     '38': 2.0,
#     '41': 2.0,
#     '42': 1.0,
#     '43': 2.0,
#     '45': 2.0,
#     '47': 1.0,
#     '48': 4.0,
#     '51': 2.0,
#     '55': 1.0,
#     '59': 2.0,
#     '66': 1.0,
#     '84': 1.0,
#     '88': 1.0,
#     '92': 1.0},
#    'passesAccurate': {'3': 2.0,
#     '5': 1.0,
#     '6': 3.0,
#     '7': 3.0,
#     '8': 1.0,
#     '9': 3.0,
#     '10': 3.0,
#     '11': 1.0,
#     '15': 2.0,
#     '16': 2.0,
#     '18': 2.0,
#     '21': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '29': 2.0,
#     '30': 1.0,
#     '32': 1.0,
#     '33': 2.0,
#     '38': 2.0,
#     '41': 2.0,
#     '42': 1.0,
#     '43': 2.0,
#     '45': 2.0,
#     '47': 1.0,
#     '48': 4.0,
#     '51': 2.0,
#     '55': 1.0,
#     '59': 2.0,
#     '66': 1.0,
#     '84': 1.0,
#     '88': 1.0,
#     '92': 1.0},
#    'passSuccess': {'3': 100.0,
#     '5': 100.0,
#     '6': 100.0,
#     '7': 100.0,
#     '8': 100.0,
#     '9': 100.0,
#     '10': 100.0,
#     '11': 100.0,
#     '15': 100.0,
#     '16': 100.0,
#     '18': 100.0,
#     '21': 100.0,
#     '22': 100.0,
#     '24': 100.0,
#     '29': 100.0,
#     '30': 100.0,
#     '32': 100.0,
#     '33': 100.0,
#     '38': 100.0,
#     '41': 100.0,
#     '42': 100.0,
#     '43': 100.0,
#     '45': 100.0,
#     '47': 100.0,
#     '48': 100.0,
#     '51': 100.0,
#     '55': 100.0,
#     '59': 100.0,
#     '66': 100.0,
#     '84': 100.0,
#     '88': 100.0,
#     '92': 100.0},
#    'aerialsTotal': {'1': 1.0},
#    'offensiveAerials': {'1': 1.0},
#    'foulsCommited': {'60': 1.0}}},
#  {'playerId': 23220,
#   'shirtNo': 36,
#   'name': 'Matteo Darmian',
#   'position': 'DMR',
#   'height': 182,
#   'weight': 70,
#   'age': 34,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 322153,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 74,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'3': 2.0,
#     '7': 1.0,
#     '10': 1.0,
#     '13': 1.0,
#     '14': 1.0,
#     '16': 1.0,
#     '18': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '21': 2.0,
#     '22': 1.0,
#     '26': 1.0,
#     '30': 1.0,
#     '33': 2.0,
#     '35': 2.0,
#     '43': 1.0,
#     '45': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '57': 3.0,
#     '59': 1.0,
#     '60': 1.0,
#     '62': 1.0},
#    'ratings': {'0': 6.0,
#     '2': 5.97,
#     '3': 5.97,
#     '7': 5.98,
#     '10': 5.98,
#     '13': 5.98,
#     '14': 5.99,
#     '16': 5.98,
#     '18': 5.97,
#     '19': 5.98,
#     '20': 6.15,
#     '21': 6.13,
#     '22': 6.13,
#     '23': 6.1,
#     '26': 6.06,
#     '30': 6.06,
#     '33': 6.05,
#     '34': 6.14,
#     '35': 6.14,
#     '36': 6.24,
#     '42': 6.29,
#     '43': 6.3,
#     '45': 6.29,
#     '47': 6.29,
#     '48': 6.29,
#     '57': 6.3,
#     '58': 6.39,
#     '59': 6.38,
#     '60': 6.38,
#     '62': 6.38,
#     '63': 6.47,
#     '66': 6.55,
#     '74': 6.73},
#    'clearances': {'42': 1.0},
#    'touches': {'0': 1.0,
#     '2': 1.0,
#     '3': 3.0,
#     '7': 1.0,
#     '10': 1.0,
#     '13': 1.0,
#     '14': 1.0,
#     '16': 2.0,
#     '18': 1.0,
#     '19': 2.0,
#     '20': 2.0,
#     '21': 2.0,
#     '22': 2.0,
#     '23': 1.0,
#     '26': 2.0,
#     '30': 1.0,
#     '31': 2.0,
#     '33': 2.0,
#     '34': 1.0,
#     '35': 2.0,
#     '38': 1.0,
#     '42': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '45': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '57': 3.0,
#     '58': 2.0,
#     '59': 2.0,
#     '60': 1.0,
#     '62': 1.0,
#     '63': 1.0,
#     '66': 1.0,
#     '69': 1.0},
#    'passesTotal': {'3': 2.0,
#     '7': 1.0,
#     '10': 1.0,
#     '13': 1.0,
#     '14': 1.0,
#     '19': 1.0,
#     '22': 1.0,
#     '30': 1.0,
#     '33': 1.0,
#     '35': 2.0,
#     '43': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '57': 3.0,
#     '60': 1.0,
#     '62': 1.0,
#     '16': 1.0,
#     '18': 1.0,
#     '26': 1.0,
#     '45': 1.0,
#     '59': 1.0},
#    'passesAccurate': {'3': 2.0,
#     '7': 1.0,
#     '10': 1.0,
#     '13': 1.0,
#     '14': 1.0,
#     '19': 1.0,
#     '22': 1.0,
#     '30': 1.0,
#     '33': 1.0,
#     '35': 2.0,
#     '43': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '57': 3.0,
#     '60': 1.0,
#     '62': 1.0},
#    'passesKey': {'20': 1.0},
#    'passSuccess': {'3': 100.0,
#     '7': 100.0,
#     '10': 100.0,
#     '13': 100.0,
#     '14': 100.0,
#     '19': 100.0,
#     '22': 100.0,
#     '30': 100.0,
#     '33': 100.0,
#     '35': 100.0,
#     '43': 100.0,
#     '47': 100.0,
#     '48': 100.0,
#     '57': 100.0,
#     '60': 100.0,
#     '62': 100.0,
#     '16': 0.0,
#     '18': 0.0,
#     '26': 0.0,
#     '45': 0.0,
#     '59': 0.0},
#    'throwInsTotal': {'0': 1.0,
#     '3': 1.0,
#     '16': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '43': 1.0,
#     '44': 1.0,
#     '58': 1.0,
#     '69': 1.0},
#    'throwInsAccurate': {'0': 1.0,
#     '3': 1.0,
#     '16': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '43': 1.0,
#     '44': 1.0},
#    'tacklesTotal': {'34': 1.0, '58': 1.0, '66': 1.0, '26': 1.0},
#    'tackleSuccessful': {'34': 1.0, '58': 1.0, '66': 1.0},
#    'tackleUnsuccesful': {'26': 1.0},
#    'tackleSuccess': {'34': 100.0, '58': 100.0, '66': 100.0, '26': 0.0},
#    'dribbledPast': {'26': 1.0}}},
#  {'playerId': 255929,
#   'shirtNo': 32,
#   'name': 'Federico Dimarco',
#   'position': 'DML',
#   'height': 175,
#   'weight': 75,
#   'age': 26,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 357897,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 74,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 1.0,
#     '3': 1.0,
#     '4': 3.0,
#     '5': 1.0,
#     '6': 1.0,
#     '9': 1.0,
#     '11': 1.0,
#     '12': 1.0,
#     '16': 1.0,
#     '20': 1.0,
#     '21': 1.0,
#     '24': 1.0,
#     '28': 1.0,
#     '29': 1.0,
#     '30': 1.0,
#     '31': 1.0,
#     '32': 1.0,
#     '41': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '46': 1.0,
#     '47': 1.0,
#     '48': 2.0,
#     '50': 1.0,
#     '62': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 2.0},
#    'ratings': {'0': 6.0,
#     '3': 6.0,
#     '4': 6.18,
#     '5': 6.17,
#     '6': 6.17,
#     '9': 6.18,
#     '11': 6.15,
#     '12': 6.14,
#     '16': 6.15,
#     '17': 6.18,
#     '20': 6.35,
#     '21': 6.36,
#     '24': 6.52,
#     '27': 6.66,
#     '28': 6.74,
#     '29': 6.74,
#     '30': 6.74,
#     '31': 6.75,
#     '32': 6.76,
#     '35': 6.81,
#     '36': 6.91,
#     '40': 6.89,
#     '41': 6.89,
#     '43': 6.9,
#     '44': 6.9,
#     '46': 6.9,
#     '47': 6.9,
#     '48': 6.9,
#     '50': 6.9,
#     '52': 6.95,
#     '57': 6.98,
#     '62': 7.06,
#     '66': 7.05,
#     '70': 7.24,
#     '72': 7.24,
#     '74': 7.42},
#    'shotsTotal': {'17': 1.0, '57': 1.0},
#    'shotsOffTarget': {'17': 1.0, '57': 1.0},
#    'clearances': {'35': 1.0, '52': 1.0},
#    'touches': {'0': 1.0,
#     '3': 1.0,
#     '4': 3.0,
#     '5': 1.0,
#     '6': 1.0,
#     '9': 1.0,
#     '11': 1.0,
#     '12': 1.0,
#     '16': 1.0,
#     '17': 1.0,
#     '20': 1.0,
#     '21': 1.0,
#     '24': 1.0,
#     '27': 1.0,
#     '28': 1.0,
#     '29': 1.0,
#     '30': 1.0,
#     '31': 1.0,
#     '32': 1.0,
#     '35': 1.0,
#     '41': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '46': 1.0,
#     '47': 2.0,
#     '48': 2.0,
#     '50': 1.0,
#     '51': 1.0,
#     '52': 1.0,
#     '57': 1.0,
#     '62': 2.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 2.0},
#    'passesTotal': {'0': 1.0,
#     '3': 1.0,
#     '4': 2.0,
#     '6': 1.0,
#     '9': 1.0,
#     '16': 1.0,
#     '21': 1.0,
#     '29': 1.0,
#     '30': 1.0,
#     '31': 1.0,
#     '32': 1.0,
#     '41': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '46': 1.0,
#     '47': 1.0,
#     '48': 2.0,
#     '50': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '11': 1.0,
#     '12': 1.0,
#     '62': 1.0},
#    'passesAccurate': {'0': 1.0,
#     '3': 1.0,
#     '4': 2.0,
#     '6': 1.0,
#     '9': 1.0,
#     '16': 1.0,
#     '21': 1.0,
#     '29': 1.0,
#     '30': 1.0,
#     '31': 1.0,
#     '32': 1.0,
#     '41': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '46': 1.0,
#     '47': 1.0,
#     '48': 1.0,
#     '50': 1.0,
#     '70': 1.0,
#     '72': 1.0},
#    'passesKey': {'4': 1.0, '20': 1.0, '24': 1.0, '70': 1.0},
#    'passSuccess': {'0': 100.0,
#     '3': 100.0,
#     '4': 100.0,
#     '6': 100.0,
#     '9': 100.0,
#     '16': 100.0,
#     '21': 100.0,
#     '29': 100.0,
#     '30': 100.0,
#     '31': 100.0,
#     '32': 100.0,
#     '41': 100.0,
#     '43': 100.0,
#     '44': 100.0,
#     '46': 100.0,
#     '47': 100.0,
#     '48': 50.0,
#     '50': 100.0,
#     '70': 100.0,
#     '72': 100.0,
#     '11': 0.0,
#     '12': 0.0,
#     '62': 0.0},
#    'aerialsTotal': {'40': 1.0},
#    'offensiveAerials': {'40': 1.0},
#    'cornersAccurate': {'4': 1.0, '20': 1.0},
#    'throwInsTotal': {'47': 1.0, '51': 1.0},
#    'throwInsAccurate': {'47': 1.0, '51': 1.0},
#    'foulsCommited': {'11': 1.0},
#    'tacklesTotal': {'27': 1.0, '62': 1.0},
#    'tackleSuccessful': {'27': 1.0, '62': 1.0},
#    'tackleSuccess': {'27': 100.0, '62': 100.0}}},
#  {'playerId': 28421,
#   'shirtNo': 22,
#   'name': 'Henrikh Mkhitaryan',
#   'position': 'MC',
#   'height': 177,
#   'weight': 75,
#   'age': 35,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'1': 2.0,
#     '2': 1.0,
#     '4': 1.0,
#     '5': 1.0,
#     '6': 2.0,
#     '10': 1.0,
#     '11': 2.0,
#     '14': 3.0,
#     '16': 1.0,
#     '17': 1.0,
#     '19': 1.0,
#     '28': 1.0,
#     '30': 4.0,
#     '35': 2.0,
#     '38': 1.0,
#     '41': 4.0,
#     '43': 1.0,
#     '44': 2.0,
#     '45': 1.0,
#     '46': 1.0,
#     '48': 2.0,
#     '50': 1.0,
#     '55': 1.0,
#     '59': 2.0,
#     '60': 1.0,
#     '64': 1.0,
#     '66': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '80': 2.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 1.0,
#     '92': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 6.01,
#     '2': 6.02,
#     '4': 6.01,
#     '5': 6.01,
#     '6': 6.01,
#     '10': 6.02,
#     '11': 6.18,
#     '12': 6.31,
#     '14': 6.32,
#     '16': 6.31,
#     '17': 6.32,
#     '19': 6.32,
#     '20': 6.28,
#     '21': 6.34,
#     '27': 6.3,
#     '28': 6.3,
#     '30': 6.32,
#     '35': 6.41,
#     '36': 6.53,
#     '38': 6.53,
#     '41': 6.53,
#     '43': 6.53,
#     '44': 6.53,
#     '45': 6.54,
#     '46': 6.54,
#     '48': 6.54,
#     '50': 6.55,
#     '52': 6.4,
#     '55': 6.41,
#     '59': 6.42,
#     '60': 6.41,
#     '61': 6.46,
#     '64': 6.47,
#     '66': 6.47,
#     '67': 6.45,
#     '72': 6.54,
#     '73': 6.54,
#     '76': 6.54,
#     '80': 6.52,
#     '82': 6.52,
#     '83': 6.49,
#     '84': 6.49,
#     '92': 6.5,
#     '94': 6.55,
#     '97': 6.7},
#    'shotsTotal': {'4': 1.0, '20': 1.0},
#    'shotsOffTarget': {'20': 1.0},
#    'shotsBlocked': {'4': 1.0},
#    'clearances': {'21': 1.0, '61': 1.0},
#    'touches': {'1': 2.0,
#     '2': 1.0,
#     '4': 2.0,
#     '5': 1.0,
#     '6': 2.0,
#     '10': 1.0,
#     '11': 3.0,
#     '12': 1.0,
#     '14': 3.0,
#     '16': 3.0,
#     '17': 1.0,
#     '19': 1.0,
#     '20': 1.0,
#     '21': 1.0,
#     '28': 1.0,
#     '30': 4.0,
#     '34': 1.0,
#     '35': 2.0,
#     '38': 1.0,
#     '41': 4.0,
#     '43': 1.0,
#     '44': 2.0,
#     '45': 1.0,
#     '46': 1.0,
#     '48': 2.0,
#     '50': 1.0,
#     '52': 1.0,
#     '55': 1.0,
#     '59': 2.0,
#     '60': 1.0,
#     '61': 1.0,
#     '64': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '79': 1.0,
#     '80': 3.0,
#     '82': 1.0,
#     '83': 3.0,
#     '84': 1.0,
#     '92': 1.0,
#     '94': 1.0},
#    'passesTotal': {'1': 2.0,
#     '2': 1.0,
#     '5': 1.0,
#     '6': 2.0,
#     '10': 1.0,
#     '11': 1.0,
#     '14': 3.0,
#     '17': 1.0,
#     '19': 1.0,
#     '28': 1.0,
#     '30': 4.0,
#     '35': 2.0,
#     '38': 1.0,
#     '41': 4.0,
#     '43': 1.0,
#     '44': 2.0,
#     '45': 1.0,
#     '46': 1.0,
#     '48': 2.0,
#     '50': 1.0,
#     '55': 1.0,
#     '59': 2.0,
#     '64': 1.0,
#     '66': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 1.0,
#     '92': 1.0,
#     '16': 1.0,
#     '60': 1.0,
#     '80': 2.0},
#    'passesAccurate': {'1': 2.0,
#     '2': 1.0,
#     '5': 1.0,
#     '6': 2.0,
#     '10': 1.0,
#     '11': 1.0,
#     '14': 3.0,
#     '17': 1.0,
#     '19': 1.0,
#     '28': 1.0,
#     '30': 3.0,
#     '35': 2.0,
#     '38': 1.0,
#     '41': 3.0,
#     '43': 1.0,
#     '44': 2.0,
#     '45': 1.0,
#     '46': 1.0,
#     '48': 2.0,
#     '50': 1.0,
#     '55': 1.0,
#     '59': 2.0,
#     '64': 1.0,
#     '66': 1.0,
#     '73': 1.0,
#     '76': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 1.0,
#     '92': 1.0},
#    'passesKey': {'11': 1.0},
#    'passSuccess': {'1': 100.0,
#     '2': 100.0,
#     '5': 100.0,
#     '6': 100.0,
#     '10': 100.0,
#     '11': 100.0,
#     '14': 100.0,
#     '17': 100.0,
#     '19': 100.0,
#     '28': 100.0,
#     '30': 75.0,
#     '35': 100.0,
#     '38': 100.0,
#     '41': 75.0,
#     '43': 100.0,
#     '44': 100.0,
#     '45': 100.0,
#     '46': 100.0,
#     '48': 100.0,
#     '50': 100.0,
#     '55': 100.0,
#     '59': 100.0,
#     '64': 100.0,
#     '66': 100.0,
#     '73': 100.0,
#     '76': 100.0,
#     '82': 100.0,
#     '83': 100.0,
#     '84': 100.0,
#     '92': 100.0,
#     '16': 0.0,
#     '60': 0.0,
#     '80': 0.0},
#    'aerialsTotal': {'11': 1.0, '35': 1.0, '67': 1.0},
#    'aerialsWon': {'11': 1.0, '35': 1.0},
#    'aerialSuccess': {'67': 0.0},
#    'offensiveAerials': {'11': 1.0, '67': 1.0},
#    'defensiveAerials': {'35': 1.0},
#    'cornersTotal': {'4': 2.0},
#    'foulsCommited': {'52': 1.0},
#    'tacklesTotal': {'12': 1.0, '27': 1.0},
#    'tackleSuccessful': {'12': 1.0},
#    'tackleUnsuccesful': {'27': 1.0},
#    'tackleSuccess': {'12': 100.0, '27': 0.0},
#    'dribbledPast': {'27': 1.0},
#    'dispossessed': {'83': 1.0}}},
#  {'playerId': 148684,
#   'shirtNo': 23,
#   'name': 'Nicolò Barella',
#   'position': 'MC',
#   'height': 175,
#   'weight': 68,
#   'age': 27,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 108860,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 90,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'1': 2.0,
#     '3': 2.0,
#     '5': 1.0,
#     '6': 2.0,
#     '9': 3.0,
#     '13': 2.0,
#     '14': 1.0,
#     '15': 2.0,
#     '16': 1.0,
#     '17': 1.0,
#     '18': 3.0,
#     '19': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '30': 2.0,
#     '32': 2.0,
#     '33': 3.0,
#     '35': 5.0,
#     '36': 1.0,
#     '41': 2.0,
#     '42': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '47': 2.0,
#     '48': 2.0,
#     '51': 1.0,
#     '54': 1.0,
#     '57': 3.0,
#     '59': 3.0,
#     '60': 1.0,
#     '62': 1.0,
#     '65': 2.0,
#     '66': 1.0,
#     '69': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '75': 1.0,
#     '76': 1.0,
#     '79': 1.0,
#     '80': 1.0,
#     '83': 4.0,
#     '84': 2.0,
#     '85': 2.0,
#     '88': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 5.97,
#     '3': 5.98,
#     '5': 5.98,
#     '6': 5.99,
#     '9': 5.99,
#     '13': 5.97,
#     '14': 5.97,
#     '15': 5.99,
#     '16': 5.99,
#     '17': 5.99,
#     '18': 6.0,
#     '19': 6.0,
#     '20': 6.01,
#     '21': 5.99,
#     '22': 5.99,
#     '23': 5.98,
#     '24': 5.98,
#     '27': 5.96,
#     '30': 5.96,
#     '32': 5.96,
#     '33': 5.97,
#     '35': 5.99,
#     '36': 6.1,
#     '41': 6.08,
#     '42': 6.15,
#     '43': 6.16,
#     '44': 6.15,
#     '47': 6.15,
#     '48': 6.16,
#     '51': 6.16,
#     '52': 6.13,
#     '54': 6.12,
#     '57': 6.21,
#     '59': 6.21,
#     '60': 6.21,
#     '62': 6.18,
#     '65': 6.28,
#     '66': 6.28,
#     '69': 6.27,
#     '70': 6.3,
#     '72': 6.3,
#     '75': 6.29,
#     '76': 6.29,
#     '77': 6.22,
#     '79': 6.22,
#     '80': 6.23,
#     '82': 6.22,
#     '83': 6.23,
#     '84': 6.37,
#     '85': 6.38,
#     '88': 6.38,
#     '90': 6.53},
#    'shotsTotal': {'15': 1.0, '70': 1.0},
#    'shotsOnTarget': {'70': 1.0},
#    'shotsBlocked': {'15': 1.0},
#    'touches': {'1': 2.0,
#     '3': 2.0,
#     '5': 2.0,
#     '6': 2.0,
#     '9': 4.0,
#     '13': 2.0,
#     '14': 1.0,
#     '15': 3.0,
#     '16': 1.0,
#     '17': 1.0,
#     '18': 3.0,
#     '19': 1.0,
#     '20': 2.0,
#     '21': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '30': 2.0,
#     '32': 2.0,
#     '33': 4.0,
#     '35': 5.0,
#     '36': 1.0,
#     '41': 2.0,
#     '42': 1.0,
#     '43': 2.0,
#     '44': 1.0,
#     '47': 2.0,
#     '48': 2.0,
#     '51': 1.0,
#     '54': 1.0,
#     '57': 3.0,
#     '59': 3.0,
#     '60': 1.0,
#     '62': 2.0,
#     '65': 2.0,
#     '66': 1.0,
#     '69': 1.0,
#     '70': 2.0,
#     '72': 1.0,
#     '75': 1.0,
#     '76': 1.0,
#     '77': 1.0,
#     '79': 1.0,
#     '80': 1.0,
#     '82': 1.0,
#     '83': 4.0,
#     '84': 3.0,
#     '85': 2.0,
#     '88': 1.0},
#    'passesTotal': {'1': 2.0,
#     '3': 2.0,
#     '5': 1.0,
#     '6': 2.0,
#     '9': 3.0,
#     '14': 1.0,
#     '15': 2.0,
#     '16': 1.0,
#     '17': 1.0,
#     '18': 3.0,
#     '19': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '30': 2.0,
#     '32': 2.0,
#     '33': 3.0,
#     '35': 5.0,
#     '41': 2.0,
#     '43': 2.0,
#     '47': 2.0,
#     '48': 2.0,
#     '51': 1.0,
#     '57': 3.0,
#     '59': 2.0,
#     '60': 1.0,
#     '62': 1.0,
#     '65': 2.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '79': 1.0,
#     '80': 1.0,
#     '83': 4.0,
#     '84': 2.0,
#     '85': 2.0,
#     '88': 1.0,
#     '13': 2.0,
#     '42': 1.0,
#     '44': 1.0,
#     '54': 1.0,
#     '69': 1.0,
#     '75': 1.0,
#     '76': 1.0},
#    'passesAccurate': {'1': 2.0,
#     '3': 2.0,
#     '5': 1.0,
#     '6': 2.0,
#     '9': 2.0,
#     '14': 1.0,
#     '15': 2.0,
#     '16': 1.0,
#     '17': 1.0,
#     '18': 3.0,
#     '19': 1.0,
#     '20': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '30': 1.0,
#     '32': 2.0,
#     '33': 3.0,
#     '35': 5.0,
#     '41': 1.0,
#     '43': 2.0,
#     '47': 2.0,
#     '48': 2.0,
#     '51': 1.0,
#     '57': 3.0,
#     '59': 2.0,
#     '60': 1.0,
#     '62': 1.0,
#     '65': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '79': 1.0,
#     '80': 1.0,
#     '83': 4.0,
#     '84': 2.0,
#     '85': 2.0,
#     '88': 1.0},
#    'passesKey': {'57': 1.0, '65': 1.0},
#    'passSuccess': {'1': 100.0,
#     '3': 100.0,
#     '5': 100.0,
#     '6': 100.0,
#     '9': 66.67,
#     '14': 100.0,
#     '15': 100.0,
#     '16': 100.0,
#     '17': 100.0,
#     '18': 100.0,
#     '19': 100.0,
#     '20': 100.0,
#     '22': 100.0,
#     '24': 100.0,
#     '30': 50.0,
#     '32': 100.0,
#     '33': 100.0,
#     '35': 100.0,
#     '41': 50.0,
#     '43': 100.0,
#     '47': 100.0,
#     '48': 100.0,
#     '51': 100.0,
#     '57': 100.0,
#     '59': 100.0,
#     '60': 100.0,
#     '62': 100.0,
#     '65': 50.0,
#     '66': 100.0,
#     '70': 100.0,
#     '72': 100.0,
#     '79': 100.0,
#     '80': 100.0,
#     '83': 100.0,
#     '84': 100.0,
#     '85': 100.0,
#     '88': 100.0,
#     '13': 0.0,
#     '42': 0.0,
#     '44': 0.0,
#     '54': 0.0,
#     '69': 0.0,
#     '75': 0.0,
#     '76': 0.0},
#    'aerialsTotal': {'42': 1.0},
#    'aerialsWon': {'42': 1.0},
#    'defensiveAerials': {'42': 1.0},
#    'throwInsTotal': {'5': 1.0},
#    'throwInsAccurate': {'5': 1.0},
#    'foulsCommited': {'23': 1.0, '27': 1.0},
#    'tacklesTotal': {'84': 1.0, '1': 1.0, '52': 1.0, '77': 1.0},
#    'tackleSuccessful': {'84': 1.0},
#    'tackleUnsuccesful': {'1': 1.0, '52': 1.0, '77': 1.0},
#    'tackleSuccess': {'84': 100.0, '1': 0.0, '52': 0.0, '77': 0.0},
#    'dribbledPast': {'1': 1.0, '52': 1.0, '77': 1.0},
#    'dribblesAttempted': {'21': 1.0, '82': 1.0},
#    'dribblesLost': {'21': 1.0, '82': 1.0},
#    'dispossessed': {'62': 1.0}}},
#  {'playerId': 110373,
#   'shirtNo': 20,
#   'name': 'Hakan Çalhanoglu',
#   'position': 'MC',
#   'height': 178,
#   'weight': 76,
#   'age': 29,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'1': 3.0,
#     '3': 2.0,
#     '4': 3.0,
#     '5': 3.0,
#     '7': 1.0,
#     '8': 2.0,
#     '9': 2.0,
#     '10': 2.0,
#     '12': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '15': 2.0,
#     '16': 3.0,
#     '17': 1.0,
#     '18': 4.0,
#     '19': 2.0,
#     '21': 1.0,
#     '22': 2.0,
#     '24': 1.0,
#     '27': 1.0,
#     '30': 3.0,
#     '31': 1.0,
#     '32': 3.0,
#     '33': 2.0,
#     '35': 4.0,
#     '38': 4.0,
#     '40': 1.0,
#     '41': 3.0,
#     '42': 1.0,
#     '43': 2.0,
#     '44': 2.0,
#     '45': 3.0,
#     '47': 2.0,
#     '48': 3.0,
#     '51': 3.0,
#     '55': 1.0,
#     '56': 1.0,
#     '57': 3.0,
#     '58': 1.0,
#     '59': 4.0,
#     '60': 2.0,
#     '62': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '73': 1.0,
#     '76': 3.0,
#     '77': 1.0,
#     '79': 2.0,
#     '82': 1.0,
#     '83': 4.0,
#     '84': 3.0,
#     '85': 3.0,
#     '90': 1.0,
#     '92': 1.0,
#     '93': 1.0,
#     '94': 1.0},
#    'ratings': {'0': 6.0,
#     '1': 5.99,
#     '3': 6.0,
#     '4': 6.1,
#     '5': 6.11,
#     '7': 6.11,
#     '8': 6.1,
#     '9': 6.11,
#     '10': 6.12,
#     '11': 6.16,
#     '12': 6.17,
#     '13': 6.18,
#     '14': 6.19,
#     '15': 6.21,
#     '16': 6.21,
#     '17': 6.22,
#     '18': 6.23,
#     '19': 6.22,
#     '21': 6.22,
#     '22': 6.24,
#     '24': 6.25,
#     '27': 6.26,
#     '30': 6.27,
#     '31': 6.27,
#     '32': 6.28,
#     '33': 6.28,
#     '35': 6.3,
#     '36': 6.41,
#     '38': 6.42,
#     '40': 6.43,
#     '41': 6.44,
#     '42': 6.43,
#     '43': 6.43,
#     '44': 6.43,
#     '45': 6.44,
#     '47': 6.45,
#     '48': 6.45,
#     '49': 6.44,
#     '51': 6.43,
#     '55': 6.43,
#     '56': 6.43,
#     '57': 6.45,
#     '58': 6.76,
#     '59': 6.78,
#     '60': 6.78,
#     '61': 6.88,
#     '62': 6.97,
#     '65': 6.95,
#     '66': 6.95,
#     '70': 6.96,
#     '72': 6.96,
#     '73': 6.96,
#     '76': 7.14,
#     '77': 7.13,
#     '79': 7.11,
#     '82': 7.1,
#     '83': 7.11,
#     '84': 7.12,
#     '85': 7.12,
#     '87': 7.17,
#     '90': 7.16,
#     '92': 7.16,
#     '93': 7.27,
#     '94': 7.27,
#     '95': 7.32,
#     '97': 7.47},
#    'shotsTotal': {'58': 1.0, '65': 1.0},
#    'shotsOnPost': {'58': 1.0},
#    'shotsOffTarget': {'58': 1.0, '65': 1.0},
#    'clearances': {'87': 1.0, '95': 1.0},
#    'interceptions': {'61': 1.0, '93': 1.0},
#    'touches': {'1': 3.0,
#     '3': 2.0,
#     '4': 3.0,
#     '5': 3.0,
#     '7': 1.0,
#     '8': 2.0,
#     '9': 2.0,
#     '10': 2.0,
#     '11': 2.0,
#     '12': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '15': 2.0,
#     '16': 3.0,
#     '17': 1.0,
#     '18': 4.0,
#     '19': 2.0,
#     '21': 1.0,
#     '22': 2.0,
#     '24': 1.0,
#     '27': 1.0,
#     '30': 3.0,
#     '31': 1.0,
#     '32': 3.0,
#     '33': 2.0,
#     '34': 1.0,
#     '35': 4.0,
#     '38': 4.0,
#     '40': 1.0,
#     '41': 3.0,
#     '42': 1.0,
#     '43': 2.0,
#     '44': 2.0,
#     '45': 3.0,
#     '47': 2.0,
#     '48': 3.0,
#     '51': 3.0,
#     '55': 1.0,
#     '56': 1.0,
#     '57': 3.0,
#     '58': 2.0,
#     '59': 4.0,
#     '60': 2.0,
#     '61': 1.0,
#     '62': 1.0,
#     '65': 1.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '73': 2.0,
#     '76': 4.0,
#     '77': 1.0,
#     '79': 2.0,
#     '80': 1.0,
#     '82': 1.0,
#     '83': 4.0,
#     '84': 3.0,
#     '85': 3.0,
#     '87': 1.0,
#     '90': 1.0,
#     '92': 1.0,
#     '93': 2.0,
#     '94': 1.0,
#     '95': 1.0},
#    'passesTotal': {'1': 2.0,
#     '3': 2.0,
#     '4': 3.0,
#     '5': 3.0,
#     '7': 1.0,
#     '8': 2.0,
#     '9': 2.0,
#     '10': 2.0,
#     '12': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '15': 2.0,
#     '16': 3.0,
#     '17': 1.0,
#     '18': 4.0,
#     '19': 2.0,
#     '21': 1.0,
#     '22': 2.0,
#     '24': 1.0,
#     '27': 1.0,
#     '30': 3.0,
#     '31': 1.0,
#     '32': 3.0,
#     '33': 2.0,
#     '35': 4.0,
#     '38': 4.0,
#     '40': 1.0,
#     '41': 3.0,
#     '43': 2.0,
#     '44': 2.0,
#     '45': 3.0,
#     '47': 2.0,
#     '48': 3.0,
#     '51': 3.0,
#     '55': 1.0,
#     '56': 1.0,
#     '57': 3.0,
#     '59': 4.0,
#     '60': 2.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '73': 1.0,
#     '76': 3.0,
#     '83': 4.0,
#     '84': 3.0,
#     '85': 2.0,
#     '92': 1.0,
#     '93': 1.0,
#     '94': 1.0,
#     '42': 1.0,
#     '77': 1.0},
#    'passesAccurate': {'1': 1.0,
#     '3': 2.0,
#     '4': 3.0,
#     '5': 3.0,
#     '7': 1.0,
#     '8': 1.0,
#     '9': 2.0,
#     '10': 2.0,
#     '12': 1.0,
#     '13': 1.0,
#     '14': 2.0,
#     '15': 2.0,
#     '16': 3.0,
#     '17': 1.0,
#     '18': 4.0,
#     '19': 1.0,
#     '21': 1.0,
#     '22': 2.0,
#     '24': 1.0,
#     '27': 1.0,
#     '30': 3.0,
#     '31': 1.0,
#     '32': 3.0,
#     '33': 2.0,
#     '35': 4.0,
#     '38': 4.0,
#     '40': 1.0,
#     '41': 3.0,
#     '43': 2.0,
#     '44': 2.0,
#     '45': 3.0,
#     '47': 2.0,
#     '48': 3.0,
#     '51': 2.0,
#     '55': 1.0,
#     '56': 1.0,
#     '57': 3.0,
#     '59': 4.0,
#     '60': 2.0,
#     '66': 1.0,
#     '70': 1.0,
#     '72': 1.0,
#     '73': 1.0,
#     '76': 3.0,
#     '83': 4.0,
#     '84': 3.0,
#     '85': 2.0,
#     '92': 1.0,
#     '93': 1.0,
#     '94': 1.0},
#    'passesKey': {'4': 1.0},
#    'passSuccess': {'1': 50.0,
#     '3': 100.0,
#     '4': 100.0,
#     '5': 100.0,
#     '7': 100.0,
#     '8': 50.0,
#     '9': 100.0,
#     '10': 100.0,
#     '12': 100.0,
#     '13': 100.0,
#     '14': 100.0,
#     '15': 100.0,
#     '16': 100.0,
#     '17': 100.0,
#     '18': 100.0,
#     '19': 50.0,
#     '21': 100.0,
#     '22': 100.0,
#     '24': 100.0,
#     '27': 100.0,
#     '30': 100.0,
#     '31': 100.0,
#     '32': 100.0,
#     '33': 100.0,
#     '35': 100.0,
#     '38': 100.0,
#     '40': 100.0,
#     '41': 100.0,
#     '43': 100.0,
#     '44': 100.0,
#     '45': 100.0,
#     '47': 100.0,
#     '48': 100.0,
#     '51': 66.67,
#     '55': 100.0,
#     '56': 100.0,
#     '57': 100.0,
#     '59': 100.0,
#     '60': 100.0,
#     '66': 100.0,
#     '70': 100.0,
#     '72': 100.0,
#     '73': 100.0,
#     '76': 100.0,
#     '83': 100.0,
#     '84': 100.0,
#     '85': 100.0,
#     '92': 100.0,
#     '93': 100.0,
#     '94': 100.0,
#     '42': 0.0,
#     '77': 0.0},
#    'foulsCommited': {'49': 1.0},
#    'tacklesTotal': {'11': 1.0},
#    'tackleSuccessful': {'11': 1.0},
#    'tackleSuccess': {'11': 100.0},
#    'dribblesWon': {'76': 1.0},
#    'dribblesAttempted': {'76': 1.0},
#    'dribbleSuccess': {'76': 100.0}}},
#  {'playerId': 299344,
#   'shirtNo': 10,
#   'name': 'Lautaro Martínez',
#   'position': 'FW',
#   'height': 174,
#   'weight': 72,
#   'age': 26,
#   'isFirstEleven': True,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'9': 1.0,
#     '10': 2.0,
#     '14': 1.0,
#     '18': 1.0,
#     '24': 1.0,
#     '30': 1.0,
#     '33': 3.0,
#     '42': 1.0,
#     '43': 1.0,
#     '44': 2.0,
#     '47': 2.0,
#     '57': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '66': 1.0,
#     '77': 1.0,
#     '88': 1.0},
#    'ratings': {'0': 6.0,
#     '9': 6.0,
#     '10': 6.0,
#     '14': 6.0,
#     '18': 6.0,
#     '19': 6.2,
#     '22': 6.24,
#     '24': 6.24,
#     '28': 6.19,
#     '30': 6.19,
#     '33': 6.2,
#     '36': 6.4,
#     '40': 6.38,
#     '42': 6.38,
#     '43': 6.38,
#     '44': 6.38,
#     '47': 6.46,
#     '50': 6.42,
#     '55': 6.39,
#     '57': 6.39,
#     '59': 6.36,
#     '62': 6.36,
#     '64': 6.36,
#     '66': 6.2,
#     '77': 6.21,
#     '88': 6.2,
#     '92': 6.24,
#     '93': 6.27,
#     '97': 6.32},
#    'shotsTotal': {'19': 1.0, '66': 1.0},
#    'shotsOffTarget': {'66': 1.0},
#    'shotsBlocked': {'19': 1.0},
#    'touches': {'9': 1.0,
#     '10': 2.0,
#     '14': 1.0,
#     '18': 1.0,
#     '19': 1.0,
#     '22': 1.0,
#     '24': 1.0,
#     '28': 1.0,
#     '30': 1.0,
#     '33': 3.0,
#     '42': 1.0,
#     '43': 1.0,
#     '44': 2.0,
#     '47': 2.0,
#     '50': 1.0,
#     '55': 1.0,
#     '57': 1.0,
#     '59': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '66': 2.0,
#     '77': 1.0,
#     '88': 1.0,
#     '92': 1.0,
#     '93': 1.0},
#    'passesTotal': {'9': 1.0,
#     '10': 2.0,
#     '14': 1.0,
#     '18': 1.0,
#     '24': 1.0,
#     '30': 1.0,
#     '33': 3.0,
#     '43': 1.0,
#     '44': 2.0,
#     '47': 2.0,
#     '57': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '66': 1.0,
#     '77': 1.0,
#     '42': 1.0,
#     '88': 1.0},
#    'passesAccurate': {'9': 1.0,
#     '10': 1.0,
#     '14': 1.0,
#     '18': 1.0,
#     '24': 1.0,
#     '30': 1.0,
#     '33': 3.0,
#     '43': 1.0,
#     '44': 2.0,
#     '47': 1.0,
#     '57': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '66': 1.0,
#     '77': 1.0},
#    'passSuccess': {'9': 100.0,
#     '10': 50.0,
#     '14': 100.0,
#     '18': 100.0,
#     '24': 100.0,
#     '30': 100.0,
#     '33': 100.0,
#     '43': 100.0,
#     '44': 100.0,
#     '47': 50.0,
#     '57': 100.0,
#     '62': 100.0,
#     '64': 100.0,
#     '66': 100.0,
#     '77': 100.0,
#     '42': 0.0,
#     '88': 0.0},
#    'aerialsTotal': {'47': 1.0},
#    'aerialsWon': {'47': 1.0},
#    'defensiveAerials': {'47': 1.0},
#    'cornersTotal': {'19': 1.0},
#    'foulsCommited': {'28': 1.0, '40': 1.0},
#    'dispossessed': {'50': 1.0}}},
#  {'playerId': 296322,
#   'shirtNo': 9,
#   'name': 'Marcus Thuram',
#   'position': 'FW',
#   'height': 192,
#   'weight': 90,
#   'age': 26,
#   'isFirstEleven': True,
#   'subbedInPlayerId': 34693,
#   'subbedOutPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedOutExpandedMinute': 78,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'0': 1.0,
#     '1': 1.0,
#     '2': 1.0,
#     '10': 2.0,
#     '11': 1.0,
#     '19': 1.0,
#     '44': 1.0,
#     '45': 1.0,
#     '47': 1.0,
#     '59': 1.0,
#     '61': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '72': 1.0,
#     '77': 1.0},
#    'ratings': {'0': 5.99,
#     '1': 6.07,
#     '2': 6.15,
#     '10': 6.16,
#     '11': 6.24,
#     '19': 6.41,
#     '21': 6.39,
#     '25': 6.47,
#     '31': 6.51,
#     '33': 6.64,
#     '35': 6.69,
#     '36': 6.89,
#     '40': 7.02,
#     '42': 7.01,
#     '44': 7.0,
#     '45': 7.01,
#     '47': 7.0,
#     '58': 6.98,
#     '59': 6.98,
#     '61': 6.96,
#     '62': 6.95,
#     '64': 6.95,
#     '71': 7.07,
#     '72': 7.07,
#     '75': 7.05,
#     '77': 7.04,
#     '78': 6.99},
#    'shotsTotal': {'24': 1.0},
#    'shotsBlocked': {'24': 1.0},
#    'clearances': {'35': 1.0},
#    'touches': {'0': 1.0,
#     '1': 1.0,
#     '2': 1.0,
#     '10': 2.0,
#     '11': 1.0,
#     '19': 1.0,
#     '21': 1.0,
#     '24': 2.0,
#     '25': 1.0,
#     '31': 2.0,
#     '33': 4.0,
#     '35': 1.0,
#     '40': 2.0,
#     '44': 1.0,
#     '45': 1.0,
#     '46': 1.0,
#     '47': 1.0,
#     '59': 2.0,
#     '61': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '71': 3.0,
#     '72': 1.0,
#     '75': 1.0,
#     '77': 1.0},
#    'passesTotal': {'10': 2.0,
#     '19': 1.0,
#     '45': 1.0,
#     '59': 1.0,
#     '72': 1.0,
#     '1': 1.0,
#     '11': 1.0,
#     '44': 1.0,
#     '47': 1.0,
#     '61': 1.0,
#     '62': 1.0,
#     '64': 1.0,
#     '77': 1.0},
#    'passesAccurate': {'10': 2.0, '19': 1.0, '45': 1.0, '59': 1.0, '72': 1.0},
#    'passesKey': {'19': 1.0},
#    'passSuccess': {'10': 100.0,
#     '19': 100.0,
#     '45': 100.0,
#     '59': 100.0,
#     '72': 100.0,
#     '1': 0.0,
#     '11': 0.0,
#     '44': 0.0,
#     '47': 0.0,
#     '61': 0.0,
#     '62': 0.0,
#     '64': 0.0,
#     '77': 0.0},
#    'aerialsTotal': {'1': 1.0,
#     '11': 1.0,
#     '19': 1.0,
#     '21': 1.0,
#     '42': 1.0,
#     '58': 1.0,
#     '61': 1.0},
#    'aerialsWon': {'1': 1.0, '11': 1.0, '19': 1.0},
#    'aerialSuccess': {'21': 0.0, '42': 0.0, '58': 0.0, '61': 0.0},
#    'offensiveAerials': {'1': 1.0,
#     '11': 1.0,
#     '19': 1.0,
#     '21': 1.0,
#     '58': 1.0,
#     '61': 1.0},
#    'defensiveAerials': {'42': 1.0},
#    'cornersTotal': {'0': 1.0, '77': 1.0},
#    'tacklesTotal': {'25': 1.0},
#    'tackleSuccessful': {'25': 1.0},
#    'tackleSuccess': {'25': 100.0},
#    'dribblesWon': {'33': 1.0, '40': 1.0, '71': 1.0},
#    'dribblesAttempted': {'33': 1.0, '40': 1.0, '71': 2.0},
#    'dribblesLost': {'71': 1.0},
#    'dribbleSuccess': {'33': 100.0, '40': 100.0, '71': 50.0},
#    'dispossessed': {'33': 1.0}}},
#  {'playerId': 34693,
#   'shirtNo': 8,
#   'name': 'Marko Arnautovic',
#   'position': 'Sub',
#   'height': 192,
#   'weight': 83,
#   'age': 34,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 78,
#   'subbedOutPlayerId': 296322,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'80': 1.0,
#     '81': 1.0,
#     '83': 1.0,
#     '84': 2.0,
#     '88': 1.0,
#     '90': 1.0,
#     '92': 1.0},
#    'ratings': {'78': 6.0,
#     '80': 5.99,
#     '81': 6.0,
#     '82': 6.03,
#     '83': 6.02,
#     '84': 6.03,
#     '88': 6.05,
#     '90': 6.13,
#     '92': 6.13,
#     '97': 6.16},
#    'shotsTotal': {'88': 1.0},
#    'shotsOnTarget': {'88': 1.0},
#    'touches': {'80': 1.0,
#     '81': 1.0,
#     '82': 1.0,
#     '83': 1.0,
#     '84': 2.0,
#     '88': 2.0,
#     '90': 1.0,
#     '92': 1.0},
#    'passesTotal': {'81': 1.0,
#     '84': 2.0,
#     '90': 1.0,
#     '80': 1.0,
#     '83': 1.0,
#     '88': 1.0,
#     '92': 1.0},
#    'passesAccurate': {'81': 1.0, '84': 2.0, '90': 1.0},
#    'passSuccess': {'81': 100.0,
#     '84': 100.0,
#     '90': 100.0,
#     '80': 0.0,
#     '83': 0.0,
#     '88': 0.0,
#     '92': 0.0},
#    'aerialsTotal': {'90': 1.0},
#    'aerialsWon': {'90': 1.0},
#    'offensiveAerials': {'90': 1.0},
#    'cornersTotal': {'88': 1.0}}},
#  {'playerId': 357897,
#   'shirtNo': 30,
#   'name': 'Carlos Augusto',
#   'position': 'Sub',
#   'height': 184,
#   'weight': 78,
#   'age': 25,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 74,
#   'subbedOutPlayerId': 255929,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'75': 1.0, '76': 1.0, '92': 2.0},
#    'ratings': {'74': 6.0,
#     '75': 6.05,
#     '76': 6.06,
#     '80': 6.19,
#     '82': 6.18,
#     '88': 6.23,
#     '92': 6.32,
#     '94': 6.45,
#     '96': 6.58,
#     '97': 6.62},
#    'clearances': {'88': 1.0, '94': 1.0, '96': 1.0},
#    'touches': {'75': 2.0,
#     '76': 1.0,
#     '80': 1.0,
#     '85': 1.0,
#     '88': 1.0,
#     '92': 2.0,
#     '94': 1.0,
#     '96': 2.0},
#    'passesTotal': {'75': 1.0, '76': 1.0, '92': 2.0},
#    'passesAccurate': {'75': 1.0, '76': 1.0, '92': 2.0},
#    'passSuccess': {'75': 100.0, '76': 100.0, '92': 100.0},
#    'aerialsTotal': {'92': 1.0, '94': 1.0, '82': 1.0},
#    'aerialsWon': {'92': 1.0, '94': 1.0},
#    'aerialSuccess': {'82': 0.0},
#    'offensiveAerials': {'82': 1.0},
#    'defensiveAerials': {'92': 1.0, '94': 1.0},
#    'throwInsTotal': {'85': 1.0},
#    'tacklesTotal': {'80': 1.0, '96': 1.0},
#    'tackleSuccessful': {'80': 1.0, '96': 1.0},
#    'tackleSuccess': {'80': 100.0, '96': 100.0}}},
#  {'playerId': 322153,
#   'shirtNo': 2,
#   'name': 'Denzel Dumfries',
#   'position': 'Sub',
#   'height': 188,
#   'weight': 80,
#   'age': 27,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 74,
#   'subbedOutPlayerId': 23220,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'74': 1.0,
#     '81': 1.0,
#     '82': 1.0,
#     '84': 2.0,
#     '85': 1.0,
#     '88': 1.0,
#     '91': 1.0},
#    'ratings': {'74': 6.0,
#     '75': 5.97,
#     '81': 6.06,
#     '82': 6.06,
#     '84': 6.05,
#     '85': 6.04,
#     '87': 6.17,
#     '88': 6.36,
#     '91': 6.33,
#     '97': 6.36},
#    'clearances': {'87': 1.0},
#    'touches': {'74': 1.0,
#     '81': 1.0,
#     '82': 1.0,
#     '84': 2.0,
#     '85': 2.0,
#     '87': 1.0,
#     '88': 1.0,
#     '91': 3.0},
#    'passesTotal': {'74': 1.0,
#     '81': 1.0,
#     '82': 1.0,
#     '84': 1.0,
#     '85': 1.0,
#     '88': 1.0,
#     '91': 1.0},
#    'passesAccurate': {'74': 1.0,
#     '81': 1.0,
#     '82': 1.0,
#     '84': 1.0,
#     '85': 1.0,
#     '88': 1.0},
#    'passesKey': {'88': 1.0},
#    'passSuccess': {'74': 100.0,
#     '81': 100.0,
#     '82': 100.0,
#     '84': 100.0,
#     '85': 100.0,
#     '88': 100.0,
#     '91': 0.0},
#    'aerialsTotal': {'81': 1.0, '87': 1.0},
#    'aerialsWon': {'81': 1.0, '87': 1.0},
#    'offensiveAerials': {'81': 1.0},
#    'defensiveAerials': {'87': 1.0},
#    'throwInsTotal': {'91': 1.0},
#    'tacklesTotal': {'75': 1.0},
#    'tackleUnsuccesful': {'75': 1.0},
#    'dribbledPast': {'75': 1.0},
#    'dribblesAttempted': {'85': 1.0, '91': 1.0},
#    'dribblesLost': {'85': 1.0, '91': 1.0}}},
#  {'playerId': 108860,
#   'shirtNo': 14,
#   'name': 'Davy Klaassen',
#   'position': 'Sub',
#   'height': 179,
#   'weight': 70,
#   'age': 30,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 90,
#   'subbedOutPlayerId': 148684,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'90': 2.0, '93': 1.0},
#    'ratings': {'90': 6.01, '93': 6.01, '95': 6.0, '97': 6.03},
#    'touches': {'90': 2.0, '93': 1.0},
#    'passesTotal': {'90': 2.0, '93': 1.0},
#    'passesAccurate': {'90': 2.0, '93': 1.0},
#    'passSuccess': {'90': 100.0, '93': 100.0},
#    'aerialsTotal': {'95': 1.0},
#    'defensiveAerials': {'95': 1.0}}},
#  {'playerId': 82399,
#   'shirtNo': 6,
#   'name': 'Stefan de Vrij',
#   'position': 'Sub',
#   'height': 190,
#   'weight': 78,
#   'age': 32,
#   'subbedInPeriod': {'value': 2, 'displayName': 'SecondHalf'},
#   'subbedInExpandedMinute': 90,
#   'subbedOutPlayerId': 329665,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {'possession': {'90': 1.0,
#     '91': 1.0,
#     '92': 1.0,
#     '94': 1.0,
#     '96': 1.0},
#    'ratings': {'90': 6.0,
#     '91': 6.0,
#     '92': 6.01,
#     '94': 6.01,
#     '96': 6.0,
#     '97': 6.04},
#    'touches': {'90': 1.0, '91': 1.0, '92': 1.0, '94': 1.0, '96': 1.0},
#    'passesTotal': {'90': 1.0, '91': 1.0, '92': 1.0, '94': 1.0, '96': 1.0},
#    'passesAccurate': {'90': 1.0, '91': 1.0, '92': 1.0, '94': 1.0},
#    'passSuccess': {'90': 100.0,
#     '91': 100.0,
#     '92': 100.0,
#     '94': 100.0,
#     '96': 0.0}}},
#  {'playerId': 423450,
#   'shirtNo': 21,
#   'name': 'Kristjan Asllani',
#   'position': 'Sub',
#   'height': 175,
#   'weight': 0,
#   'age': 21,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 371027,
#   'shirtNo': 17,
#   'name': 'Tajon Buchanan',
#   'position': 'Sub',
#   'height': 183,
#   'weight': 68,
#   'age': 24,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 25244,
#   'shirtNo': 70,
#   'name': 'Alexis Sánchez',
#   'position': 'Sub',
#   'height': 169,
#   'weight': 62,
#   'age': 35,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 349126,
#   'shirtNo': 31,
#   'name': 'Yann Bisseck',
#   'position': 'Sub',
#   'height': 196,
#   'weight': 83,
#   'age': 23,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 331425,
#   'shirtNo': 16,
#   'name': 'Davide Frattesi',
#   'position': 'Sub',
#   'height': 178,
#   'weight': 74,
#   'age': 24,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 136306,
#   'shirtNo': 5,
#   'name': 'Stefano Sensi',
#   'position': 'Sub',
#   'height': 168,
#   'weight': 62,
#   'age': 28,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 122963,
#   'shirtNo': 12,
#   'name': 'Raffaele Di Gennaro',
#   'position': 'Sub',
#   'height': 186,
#   'weight': 80,
#   'age': 30,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}},
#  {'playerId': 254692,
#   'shirtNo': 77,
#   'name': 'Emil Audero',
#   'position': 'Sub',
#   'height': 190,
#   'weight': 83,
#   'age': 27,
#   'isManOfTheMatch': False,
#   'field': 'home',
#   'stats': {}}]

# %%
# Pydantic model for play info
class Player(BaseModel):
    
    # Player Identifier
    player_id: int
        
    # Shirt number
    shirt_no: int
    
    # Player's name
    name: str
        
    # Player's age
    age: int
        
    # Player's position
    position: str
        
     # Which team they're on
    team_id: int

# %%
# Insert player information into 'players' table
def insert_players(team_info, supabase):
    players = []
    # Extract player details from team info
    for team in team_info:
        for player in team['players']:
            players.append({
                'player_id': player['playerId'],
                'team_id': team['team_id'],
                'shirt_no': player['shirtNo'],
                'name': player['name'],
                'position': player['position'],
                'age': player['age']
            })
    # Use Supabase upsert to insert or update records in 'players' table        
    execution = supabase.table('players').upsert(players).execute()

# %%
insert_players(team_info, supabase)
# Out:
# 2024-02-07 17:28:21,950:INFO - HTTP Request: POST https://vrvkafgbdruqmzszmaln.supabase.co/rest/v1/players "HTTP/1.1 200 OK"

# %%
import psycopg2

conn = psycopg2.connect(
    user="postgres.vrvkafgbdruqmzszmaln",
    password=supabase_password,
    host="aws-0-ca-central-1.pooler.supabase.com",
    port=5432,
    database="postgres"

)

# %%
# Create cursor object to interact with database
cursor = conn.cursor()

# %%
# Execute SQL query to select all from 'players' table
cursor.execute("""
    SELECT * FROM players;
""")

# %%
# Fetch all records and put into 'records'
records = cursor.fetchall()

# %%
records
# Out:
# [(35758, 1, 'Yann Sommer', 35, 'GK', 75),
#  (259648, 28, 'Benjamin Pavard', 27, 'DC', 75),
#  (329665, 95, 'Alessandro Bastoni', 24, 'DC', 75),
#  (54968, 15, 'Francesco Acerbi', 35, 'DC', 75),
#  (23220, 36, 'Matteo Darmian', 34, 'DMR', 75),
#  (255929, 32, 'Federico Dimarco', 26, 'DML', 75),
#  (28421, 22, 'Henrikh Mkhitaryan', 35, 'MC', 75),
#  (148684, 23, 'Nicolò Barella', 27, 'MC', 75),
#  (110373, 20, 'Hakan Çalhanoglu', 29, 'MC', 75),
#  (299344, 10, 'Lautaro Martínez', 26, 'FW', 75),
#  (296322, 9, 'Marcus Thuram', 26, 'FW', 75),
#  (34693, 8, 'Marko Arnautovic', 34, 'Sub', 75),
#  (357897, 30, 'Carlos Augusto', 25, 'Sub', 75),
#  (322153, 2, 'Denzel Dumfries', 27, 'Sub', 75),
#  (108860, 14, 'Davy Klaassen', 30, 'Sub', 75),
#  (82399, 6, 'Stefan de Vrij', 32, 'Sub', 75),
#  (423450, 21, 'Kristjan Asllani', 21, 'Sub', 75),
#  (371027, 17, 'Tajon Buchanan', 24, 'Sub', 75),
#  (25244, 70, 'Alexis Sánchez', 35, 'Sub', 75),
#  (349126, 31, 'Yann Bisseck', 23, 'Sub', 75),
#  (331425, 16, 'Davide Frattesi', 24, 'Sub', 75),
#  (136306, 5, 'Stefano Sensi', 28, 'Sub', 75),
#  (122963, 12, 'Raffaele Di Gennaro', 30, 'Sub', 75),
#  (254692, 77, 'Emil Audero', 27, 'Sub', 75),
#  (73379, 1, 'Wojciech Szczesny', 33, 'GK', 87),
#  (339875, 3, 'Bremer', 26, 'DC', 87),
#  (88300, 6, 'Danilo', 32, 'DC', 87),
#  (439909, 4, 'Federico Gatti', 25, 'DC', 87),
#  (423440, 27, 'Andrea Cambiaso', 23, 'DMR', 87),
#  (105995, 11, 'Filip Kostic', 31, 'DML', 87),
#  (116609, 25, 'Adrien Rabiot', 28, 'MC', 87),
#  (273539, 5, 'Manuel Locatelli', 26, 'MC', 87),
#  (338275, 16, 'Weston McKennie', 25, 'MC', 87),
#  (315369, 9, 'Dusan Vlahovic', 24, 'FW', 87),
#  (494525, 15, 'Kenan Yildiz', 18, 'FW', 87),
#  (100995, 12, 'Alex Sandro', 33, 'Sub', 87),
#  (322971, 7, 'Federico Chiesa', 26, 'Sub', 87),
#  (425080, 20, 'Fabio Miretti', 20, 'Sub', 87),
#  (353991, 22, 'Timothy Weah', 23, 'Sub', 87),
#  (391348, 26, 'Carlos Alcaraz', 21, 'Sub', 87),
#  (83981, 23, 'Carlo Pinsoglio', 33, 'Sub', 87),
#  (78880, 36, 'Mattia Perin', 31, 'Sub', 87),
#  (371257, 41, 'Hans Nicolussi Caviglia', 23, 'Sub', 87),
#  (116207, 24, 'Daniele Rugani', 29, 'Sub', 87),
#  (367181, 33, 'Tiago Djaló', 23, 'Sub', 87),
#  (438894, 17, 'Samuel Iling-Junior', 20, 'Sub', 87),
#  (468853, 47, 'Joseph Nonge', 18, 'Sub', 87)]

# %%
# Create DataFrame using fetched records and column names from cursor description
df = pd.DataFrame(records, columns=[desc[0] for desc in cursor.description])

# %%
df.head(5)
# Out:
#    player_id  shirt_no                name  age position  team_id
# 0      35758         1         Yann Sommer   35       GK       75
# 1     259648        28     Benjamin Pavard   27       DC       75
# 2     329665        95  Alessandro Bastoni   24       DC       75
# 3      54968        15    Francesco Acerbi   35       DC       75
# 4      23220        36      Matteo Darmian   34      DMR       75

# %% [markdown]
# # Web Scraping a Team's Entire Season

# %%
# Pydantic model for match events
class MatchEvent(BaseModel):
    id: int
    event_id: int
    minute: int
    second: Optional[float] = None
    team_id: int
    player_id: int
    x: float
    y: float
    end_x: Optional[float] = None
    end_y: Optional[float] = None
    qualifiers: List[dict]
    is_touch: bool
    blocked_x: Optional[float] = None
    blocked_y: Optional[float] = None
    goal_mouth_z: Optional[float] = None
    goal_mouth_y: Optional[float] = None
    is_shot: bool
    card_type: bool
    is_goal: bool
    type_display_name: str
    outcome_type_display_name: str
    period_display_name: str

# %%
# Insert match events into Supabase tables
def insert_match_events(df, supabase):
    events = [
        MatchEvent(**x).dict()
        for x in df.to_dict(orient='records')
    ]
    execution = supabase.table('match_events').upsert(events).execute()

# %%
# Pydantic model for play info
class Player(BaseModel):
    player_id: int
    shirt_no: int
    name: str
    age: int
    position: str
    team_id: int

# %%
# Insert player information into 'players' table
def insert_players(team_info, supabase):
    players = []
    for team in team_info:
        for player in team['players']:
            players.append({
                'player_id': player['playerId'],
                'team_id': team['team_id'],
                'shirt_no': player['shirtNo'],
                'name': player['name'],
                'position': player['position'],
                'age': player['age']
            })
            
    execution = supabase.table('players').upsert(players).execute()

# %%
# Supabase Info
supabase_password = '7eZZSE#$e+U6B.s'
project_url = 'https://vrvkafgbdruqmzszmaln.supabase.co'
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InZydmthZmdiZHJ1cW16c3ptYWxuIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MDcyMzQ1OTAsImV4cCI6MjAyMjgxMDU5MH0.RnA_99mq99SmSYLTuin-GFSOt5ax4mCThVGXYVFov9A'
supabase = create_client(project_url, api_key)

# %%
# # Initiate chrome webdriver using selenium
driver = webdriver.Chrome()

# %%
# Scrapes match events from given Whoscored URL
# Processes the scraped data into a DataFrame
# Maps and transforms DataFrame columns
# Filters and cleans the DataFrame
# Inserts cleaned match events into Supabase table using insert_match_events function
# Extracts team information and inserts it into a Supabase table using the insert_players function
# Returns 'Success' message if the process is completed successfully
def scrape_match_events(whoscored_url, driver):
    
    driver.get(whoscored_url)
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    element = soup.select_one('script:-soup-contains("matchCentreData")')
    matchdict = json.loads(element.text.split("matchCentreData: ")[1].split(',\n')[0])
    
    match_events = matchdict['events']
    
    df = pd.DataFrame(match_events)
    
    df.dropna(subset='playerId', inplace=True)
    
    df = df.where(pd.notnull(df), None)
    
    df = df.rename(
    {
        'eventId': 'event_id',
        'expandedMinute': 'expanded_minute',
        'outcomeType': 'outcome_type',
        'isTouch': 'is_touch',
        'playerId': 'player_id',
        'teamId': 'team_id',
        'endX': 'end_x',
        'endY': 'end_y',
        'blockedX': 'blocked_x',
        'blockedY': 'blocked_y',
        'goalMouthZ': 'goal_mouth_z',
        'goalMouthY': 'goal_mouth_y',
        'isShot': 'is_shot',
        'cardType': 'card_type',
        'isGoal': 'is_goal'
    },
        axis=1
    )
    
    df['period_display_name'] = df['period'].apply(lambda x: x['displayName'])
    df['type_display_name'] = df['type'].apply(lambda x: x['displayName'])
    df['outcome_type_display_name'] = df['outcome_type'].apply(lambda x: x['displayName'])
    
    df.drop(columns=["period", "type", "outcome_type"], inplace=True)
    
    if 'is_goal' not in df.columns:
        df['is_goal'] = False
        
    if 'is_card' not in df.columns:
        df['is_card'] = False
        df['card_type'] = False
        
    df = df[~(df['type_display_name'] == "OffsideGiven")]
    
    df = df[[
        'id', 'event_id', 'minute', 'second', 'team_id', 'player_id', 'x', 'y', 'end_x', 'end_y',
        'qualifiers', 'is_touch', 'blocked_x', 'blocked_y', 'goal_mouth_z', 'goal_mouth_y', 'is_shot',
        'card_type', 'is_goal', 'type_display_name', 'outcome_type_display_name',
        'period_display_name'
    ]]
    
    df[['id', 'event_id', 'minute', 'team_id', 'player_id']] = df[['id', 'event_id', 'minute', 'team_id', 'player_id']].astype(np.int64)
    df[['second', 'x', 'y', 'end_x', 'end_y']] = df[['second', 'x', 'y', 'end_x', 'end_y']].astype(float)
    df[['is_shot', 'is_goal', 'card_type']] = df[['is_shot', 'is_goal', 'card_type']].astype(bool)
    
    df['is_goal'] = df['is_goal'].fillna(False)
    df['is_shot'] = df['is_shot'].fillna(False)
    
    for column in df.columns:
        if df[column].dtype == np.float64 or df[column].dtype == np.float32:
            df[column] = np.where(
                np.isnan(df[column]),
                None,
                df[column]
            )
            
            
    insert_match_events(df, supabase)
    
    
    team_info = []
    team_info.append({
        'team_id': matchdict['home']['teamId'],
        'name': matchdict['home']['name'],
        'country_name': matchdict['home']['countryName'],
        'manager_name': matchdict['home']['managerName'],
        'players': matchdict['home']['players'],
    })

    team_info.append({
        'team_id': matchdict['away']['teamId'],
        'name': matchdict['away']['name'],
        'country_name': matchdict['away']['countryName'],
        'manager_name': matchdict['away']['managerName'],
        'players': matchdict['away']['players'],
    })
    
    insert_players(team_info, supabase)
    
    return print('Success')

# %%
# Navigates to a team's fixtures page (on Whoscored)
# Waits 3 seconds for page to load before further actions
driver.get('https://www.whoscored.com/Teams/80/Fixtures/Italy-AC-Milan')
time.sleep(3)

# %%
# Creates BS object by parsing HTML source code of web page using 'html.parser'
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Extracts all URLs containing "/Live/" in href attribute from
# anchor (a) elements in parsed HTML using BeautifulSoup.
all_urls = soup.select('a[href*="\/Live\/"]')

# %%
# Creates list of URLs by combining the base URL "https://www.whoscored.com" 
# with href attribute of each anchor element in the list of URLs 
# Note: Converts the list to a set and back to a list to help remove duplicate URLs
all_urls = list(set([
    'https://www.whoscored.com' + x.attrs['href']
    for x in all_urls
]))

# %%
all_urls
# Out:
# ['https://www.whoscored.com/Matches/1785206/Live/Italy-Coppa-Italia-2023-2024-AC-Milan-Cagliari',
#  'https://www.whoscored.com/Matches/1746090/Live/Italy-Serie-A-2023-2024-Cagliari-AC-Milan',
#  'https://www.whoscored.com/Matches/1746113/Live/Italy-Serie-A-2023-2024-Genoa-AC-Milan',
#  'https://www.whoscored.com/Matches/1746165/Live/Italy-Serie-A-2023-2024-Lecce-AC-Milan',
#  'https://www.whoscored.com/Matches/1746175/Live/Italy-Serie-A-2023-2024-AC-Milan-Frosinone',
#  'https://www.whoscored.com/Matches/1746251/Live/Italy-Serie-A-2023-2024-AC-Milan-Roma',
#  'https://www.whoscored.com/Matches/1746286/Live/Italy-Serie-A-2023-2024-Frosinone-AC-Milan',
#  'https://www.whoscored.com/Matches/1746126/Live/Italy-Serie-A-2023-2024-AC-Milan-Juventus',
#  'https://www.whoscored.com/Matches/1794755/Live/Italy-Coppa-Italia-2023-2024-AC-Milan-Atalanta',
#  'https://www.whoscored.com/Matches/1746226/Live/Italy-Serie-A-2023-2024-AC-Milan-Sassuolo',
#  'https://www.whoscored.com/Matches/1746073/Live/Italy-Serie-A-2023-2024-Inter-AC-Milan',
#  'https://www.whoscored.com/Matches/1775687/Live/Europe-Champions-League-2023-2024-AC-Milan-Borussia-Dortmund',
#  'https://www.whoscored.com/Matches/1746201/Live/Italy-Serie-A-2023-2024-Empoli-AC-Milan',
#  'https://www.whoscored.com/Matches/1746069/Live/Italy-Serie-A-2023-2024-Roma-AC-Milan',
#  'https://www.whoscored.com/Matches/1746238/Live/Italy-Serie-A-2023-2024-Udinese-AC-Milan',
#  'https://www.whoscored.com/Matches/1746139/Live/Italy-Serie-A-2023-2024-Napoli-AC-Milan',
#  'https://www.whoscored.com/Matches/1746108/Live/Italy-Serie-A-2023-2024-AC-Milan-Lazio',
#  'https://www.whoscored.com/Matches/1775681/Live/Europe-Champions-League-2023-2024-Borussia-Dortmund-AC-Milan',
#  'https://www.whoscored.com/Matches/1746053/Live/Italy-Serie-A-2023-2024-AC-Milan-Torino',
#  'https://www.whoscored.com/Matches/1746087/Live/Italy-Serie-A-2023-2024-AC-Milan-Verona',
#  'https://www.whoscored.com/Matches/1746160/Live/Italy-Serie-A-2023-2024-AC-Milan-Fiorentina',
#  'https://www.whoscored.com/Matches/1775685/Live/Europe-Champions-League-2023-2024-AC-Milan-Paris-Saint-Germain',
#  'https://www.whoscored.com/Matches/1746218/Live/Italy-Serie-A-2023-2024-Salernitana-AC-Milan',
#  'https://www.whoscored.com/Matches/1775684/Live/Europe-Champions-League-2023-2024-Paris-Saint-Germain-AC-Milan',
#  'https://www.whoscored.com/Matches/1746252/Live/Italy-Serie-A-2023-2024-AC-Milan-Bologna',
#  'https://www.whoscored.com/Matches/1746194/Live/Italy-Serie-A-2023-2024-AC-Milan-Monza',
#  'https://www.whoscored.com/Matches/1746180/Live/Italy-Serie-A-2023-2024-Atalanta-AC-Milan',
#  'https://www.whoscored.com/Matches/1775679/Live/Europe-Champions-League-2023-2024-AC-Milan-Newcastle',
#  'https://www.whoscored.com/Matches/1775689/Live/Europe-Champions-League-2023-2024-Newcastle-AC-Milan',
#  'https://www.whoscored.com/Matches/1746151/Live/Italy-Serie-A-2023-2024-AC-Milan-Udinese',
#  'https://www.whoscored.com/Matches/1746040/Live/Italy-Serie-A-2023-2024-Bologna-AC-Milan']

# %%
# Go through list of URLs and prints then calls 'scrap_match_events' for each
# 2 second delay between iterations
for url in all_urls:
    print(url)
    scrape_match_events(
        whoscored_url=url,
        driver=driver
    )
    time.sleep(2)
# Out:
# https://www.whoscored.com/Matches/1785206/Live/Italy-Coppa-Italia-2023-2024-AC-Milan-Cagliari
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[199], line 5
#       3 for url in all_urls:
#       4     print(url)
# ----> 5     scrape_match_events(
#       6         whoscored_url=url,
#       7         driver=driver
#       8     )
#       9     time.sleep(2)
#
# Cell In[193], line 15, in scrape_match_events(whoscored_url, driver)
#      12 soup = BeautifulSoup(driver.page_source, 'html.parser')
#      14 element = soup.select_one('script:-soup-contains("matchCentreData")')
# ---> 15 matchdict = json.loads(element.text.split("matchCentreData: ")[1].split(',\n')[0])
#      17 match_events = matchdict['events']
#      19 df = pd.DataFrame(match_events)
#
# AttributeError: 'NoneType' object has no attribute 'text'
